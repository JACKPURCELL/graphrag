# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 设置 Seaborn 风格
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'Optima'
plt.rcParams['font.weight'] = 'bold'
# plt.rcParams['font.size'] = 16
# Nature 杂志风格的配色方案
colors = sns.color_palette("muted")

x = [0,1, 3, 5, 10]  # 只有四个数据点


#${{N_\alpha}}$
data1 = [[[1, 72.6], [3, 74.7], [5, 69.5], [10, 81.1]],
           [[1, 75.7], [3, 83.5], [5, 82.5], [10, 76.7]],
           [[1,97.3],[3,96.5],[5,94.7],[10,98.2]]]
# 89,87,89,92
# 86.1,86.1,84.7,88.9
# data1_prenode = [[[1,40],[3,53],[5,60]]]
#middle node$
# data2 = [[[1, 85], ,
#            [[1, 86], ]]
data2 = [[[1, 92.6], [3, 96.3], [5, 98.3]],
           [[1, 88.9], [2, 78.6],  [5, 92.3]],
           [[1,87.8],[3,89.2],[5,90.3]]]
#$|V_{r,n}^{l}|$ enhance
data3= [[[0,23.2],[1, 57.9], [3, 65.3], [5, 81.1]],
           [[0,28.2], [1, 63.1], [3, 68.9], [5, 76.7]],
           [[0,29.2],[1,91.2],[3,95.6],[5,98.2]]]


#replication
data4= [[[1, 92.6], [3, 74.7], [5, 76.8],[10,75.8]],
           [[1, 76.7], [3, 76.7], [5, 81.6],[10,84.5]],
           [[1,98.2],[3,94.7],[5,97.3],[10,92.0]]]


data_full = [data1, data2, data3, data4]
# 创建一个包含4个子图的图形
fig, axes = plt.subplots(1, 4, figsize=(16, 4), sharey=True)  # Use sharey=True for consistent y-axis

# 为每个子图设置不同的 x 轴标签和刻度标签
x_labels = [
    r'Number of $N_\alpha$ corpus generation for Direct Attack',
    r'Number of $|\upsilon_{r, n}^{t}|^{\prime}$ in Direct Attack',
    r'Number of $|V_{r,n}^{l}|$ in Indirect Attack',
    'Number of Text Replication'
]

x_tick_labels = [
    ['0','1', '3', '5', '10'],
    ['0','1', '3', '5', '10'],
    ['0','1', '3', '5', '10'],
    ['0','1', '3', '5', '10'],

]

# 自定义的图例标签
legend_labels = [
    r'$\text{Label 1}$',
    r'$\text{Label 2}$',
    r'$\text{Label 3}$',
    r'$\text{Label 4}$'
]

# 绘制每个子图
for i, ax in enumerate(axes):

    ax.plot([d[0] for d in data_full[i][0]], [d[1] for d in data_full[i][0]], marker='o', color=colors[0], label='geographic')
    ax.plot([d[0] for d in data_full[i][1]], [d[1] for d in data_full[i][1]], marker='o', color=colors[1], label='Med')
    ax.plot([d[0] for d in data_full[i][2]], [d[1] for d in data_full[i][2]], marker='o', color=colors[2], label='cybersecurity')
   
    ax.set_xlabel(x_labels[i],fontweight='bold')  # 设置不同的 x 轴标签
    if i == 0:
        ax.set_ylabel('ASR',fontweight='bold')  # Ensure y-axis label is set for each subplot
    ax.set_xticks(x)
    ax.set_xticklabels(x_tick_labels[i])  # 设置不同的 x 轴刻度标签
    if i == 0:
        ax.legend()
    # 添加网格线
    ax.grid(True, linestyle='--')

    # 隐藏特定的边框
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(True)  # 显示左边框

    # 保留 y 轴的刻度线
    ax.tick_params(axis='y', length=0)

# 调整布局
plt.tight_layout()
plt.savefig('ablation.pdf')

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 设置 Seaborn 风格
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'Optima'
plt.rcParams['font.weight'] = 'bold'
# plt.rcParams['font.size'] = 16
# Nature 杂志风格的配色方案
colors = sns.color_palette("muted")

x = [0,1, 3, 5, 10]  # 只有四个数据点


#${{N_\alpha}}$
data1 = [[[1, 72.6], [3, 81.1], [5, 80.6], [10, 82.6]],
           [[1, 75.7], [3, 83.5], [5, 83.5], [10, 82.3]],
           [[1,97.3],[3,98.2],[5,98.7],[10,98.2]]]
# 89,87,89,92
# 86.1,86.1,84.7,88.9
# data1_prenode = [[[1,40],[3,53],[5,60]]]
#middle node$
# data2 = [[[1, 85], ,
#            [[1, 86], ]]

#$|V_{r,n}^{l}|$ enhance
data3= [[[0,23.2],[1, 57.9], [3, 65.3], [5, 81.1],[10, 82.7]],
           [[0,28.2], [1, 63.1], [3, 68.9], [5, 83.5],[10, 84.8]],
           [[0,29.2],[1,91.2],[3,95.6],[5,98.2],[10,98.7]]]


#replication
data4= [[[1, 81.1], [3, 74.7], [5, 76.8],[10,75.8]],
           [[1, 83.5], [3, 82.5], [5, 81.6],[10,84.5]],
           [[1,98.2],[3,94.7],[5,97.3],[10,92.0]]]


data_full = [data1,  data3, data4]
# 创建一个包含4个子图的图形
fig, axes = plt.subplots(1, 3, figsize=(12, 4), sharey=True)  # Use sharey=True for consistent y-axis

# 为每个子图设置不同的 x 轴标签和刻度标签
x_labels = [
    r'Number of Poisoning Text Variants',
    r'Number of Supporting Relations',
    'Total Length of Poisoning Text'
]

x_tick_labels = [
    ['0','1', '3', '5', '10'],
    ['0','1', '3', '5', '10'],
    ['0','1', '3', '5', '10'],

]



# 绘制每个子图
for i, ax in enumerate(axes):

    ax.plot([d[0] for d in data_full[i][0]], [d[1] for d in data_full[i][0]], marker='o', color=colors[0], label='Geographic')
    ax.plot([d[0] for d in data_full[i][1]], [d[1] for d in data_full[i][1]], marker='o', color=colors[1], label='Medical')
    ax.plot([d[0] for d in data_full[i][2]], [d[1] for d in data_full[i][2]], marker='o', color=colors[2], label='Cybersecurity')
   
    ax.set_xlabel(x_labels[i],fontweight='bold')  # 设置不同的 x 轴标签
    if i == 0:
        ax.set_ylabel('ASR',fontweight='bold')  # Ensure y-axis label is set for each subplot
    ax.set_xticks(x)
    ax.set_xticklabels(x_tick_labels[i])  # 设置不同的 x 轴刻度标签
    if i == 0:
        ax.legend()
    # 添加网格线
    ax.grid(True, linestyle='--')

    # 隐藏特定的边框
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(True)  # 显示左边框

    # 保留 y 轴的刻度线
    ax.tick_params(axis='y', length=0)

# 调整布局
plt.tight_layout()
plt.savefig('ablation.pdf')

# 显示图形
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 设置 Seaborn 风格
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'Optima'
plt.rcParams['font.weight'] = 'bold'
plt.rcParams['font.size'] = 16
# Nature 杂志风格的配色方案
colors = sns.color_palette("muted")

x = [0, 1, 3, 5, 10]  # 只有四个数据点

#${{N_\alpha}}$
data1 = [[[1, 78.3], [3, 91.1], [5, 91.1], [10, 92.1]],
         [[1, 72.6], [3, 81.1], [5, 80.6], [10, 82.6]],
         [[1, 75.7], [3, 83.5], [5, 83.5], [10, 82.3]],
         [[1, 97.3], [3, 98.2], [5, 98.7], [10, 98.2]]]

#$|V_{r,n}^{l}|$ enhance
data3 = [[[0, 31.3], [1, 54.6], [3, 71.4], [5, 91.1], [10, 92.1]],
         [[0, 23.2], [1, 57.9], [3, 65.3], [5, 81.1], [10, 82.7]],
         [[0, 28.2], [1, 63.1], [3, 68.9], [5, 83.5], [10, 84.8]],
         [[0, 29.2], [1, 91.2], [3, 95.6], [5, 98.2], [10, 98.7]]]

#replication
data4 = [[[1, 91.1], [3, 92.1], [5, 92.1], [10, 92.4]],
         [[1, 81.1], [3, 74.7], [5, 76.8], [10, 75.8]],
         [[1, 83.5], [3, 82.5], [5, 81.6], [10, 84.5]],
         [[1, 98.2], [3, 94.7], [5, 97.3], [10, 92.0]]]

data_full = [data1, data3, data4]

# 为每个子图设置不同的 x 轴标签和刻度标签
x_labels = [
    r'Number of Poisoning Text Variants per Relation Injection ($N_\alpha$)',
    r'Number of Supporting Relations per Relation Injection ($N_\beta$)',
    'Number of Poisoning Text Replications'
]

x_tick_labels = [
    ['0', '1', '3', '5', '10'],
    ['0', '1', '3', '5', '10'],
    ['0', '1', '3', '5', '10'],
    ['0', '1', '3', '5', '10'],
]

# 绘制每个图并保存
for i in range(3):
    fig, ax = plt.subplots(figsize=(7, 4))
    ax.plot([d[0] for d in data_full[i][0]], [d[1] for d in data_full[i][0]], marker='o', color=colors[3], label='MuSiQue', linewidth=2)
    ax.plot([d[0] for d in data_full[i][1]], [d[1] for d in data_full[i][1]], marker='o', color=colors[0], label='Geographic', linewidth=2)
    ax.plot([d[0] for d in data_full[i][2]], [d[1] for d in data_full[i][2]], marker='o', color=colors[1], label='Medical', linewidth=2)
    ax.plot([d[0] for d in data_full[i][3]], [d[1] for d in data_full[i][3]], marker='o', color=colors[2], label='Cybersecurity', linewidth=2)

    ax.set_xlabel(x_labels[i], fontweight='bold', fontsize=16)
    ax.set_ylabel('ASR', fontweight='bold', fontsize=16)
    ax.set_xticks(x)
    ax.set_xticklabels(x_tick_labels[i], fontsize=16)
    ax.legend(fontsize=16, loc='lower right')
    ax.grid(True, linestyle='--')

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(True)

    ax.tick_params(axis='y', length=0, labelsize=16)

    # 设置 y 轴区间
    if i in [0, 2]:  # 第1和第3个子图
        ax.set_ylim(55, 100)
    if i == 1:
        ax.set_ylim(20, 100)

    plt.tight_layout()
    plt.savefig(f'ablation_{i+1}.pdf')
    plt.close(fig)

# %%
#adjust to agnostic
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 设置 Seaborn 风格
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'Optima'
plt.rcParams['font.weight'] = 'bold'
plt.rcParams['font.size'] = 16
# Nature 杂志风格的配色方案
colors = sns.color_palette("muted")

x = [0, 1, 3, 5, 10]  # 只有四个数据点

#${{N_\alpha}}$
data1 = [[[1, 72.6], [3, 81.1], [5, 80.6], [10, 82.6]],
         [[1, 75.7], [3, 83.5], [5, 83.5], [10, 82.3]],
         [[1, 97.3], [3, 98.2], [5, 98.7], [10, 98.2]]]

#$|V_{r,n}^{l}|$ enhance
data3 = [[[0, 23.2], [1, 57.9], [3, 65.3], [5, 81.1], [10, 82.7]],
         [[0, 28.2], [1, 63.1], [3, 68.9], [5, 83.5], [10, 84.8]],
         [[0, 29.2], [1, 91.2], [3, 95.6], [5, 98.2], [10, 98.7]]]

#replication
data4 = [[[1, 81.1], [3, 74.7], [5, 76.8], [10, 75.8]],
         [[1, 83.5], [3, 82.5], [5, 81.6], [10, 84.5]],
         [[1, 98.2], [3, 94.7], [5, 97.3], [10, 92.0]]]

data_full = [data1, data3, data4]

# 为每个子图设置不同的 x 轴标签和刻度标签
x_labels = [
    r'Number of Poisoning Text Variants per Relation Injection ($N_\alpha$)',
    r'Number of Supporting Relations per Relation Injection ($N_\beta$)',
    'Number of Poisoning Text Replications'
]

x_tick_labels = [
    ['0', '1', '3', '5', '10'],
    ['0', '1', '3', '5', '10'],
    ['0', '1', '3', '5', '10'],
]

# 绘制每个图并保存
for i in range(3):
    fig, ax = plt.subplots(figsize=(7, 4))

    ax.plot([d[0] for d in data_full[i][0]], [d[1] for d in data_full[i][0]], marker='o', color=colors[0], label='Geographic', linewidth=2)
    ax.plot([d[0] for d in data_full[i][1]], [d[1] for d in data_full[i][1]], marker='o', color=colors[1], label='Medical', linewidth=2)
    ax.plot([d[0] for d in data_full[i][2]], [d[1] for d in data_full[i][2]], marker='o', color=colors[2], label='Cybersecurity', linewidth=2)

    ax.set_xlabel(x_labels[i], fontweight='bold', fontsize=16)
    ax.set_ylabel('ASR', fontweight='bold', fontsize=16)
    ax.set_xticks(x)
    ax.set_xticklabels(x_tick_labels[i], fontsize=16)
    ax.legend(fontsize=16, loc='lower right')
    ax.grid(True, linestyle='--')

    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(True)

    ax.tick_params(axis='y', length=0, labelsize=16)

    # 设置 y 轴区间
    if i in [0, 2]:  # 第1和第3个子图
        ax.set_ylim(55, 100)
    if i == 1:
        ax.set_ylim(20, 100)

    plt.tight_layout()
    plt.savefig(f'ablation_{i+1}.pdf')
    plt.close(fig)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'Optima'
plt.rcParams['font.weight'] = 'bold'

# Define colors
colors = sns.color_palette("muted")

# Data for the plots
data_default = {
    'geographic': [(32, 34.7), (62.7, 52.6), (99.6, 53.7), (122.1, 60), (152.1, 61.3)],
    'medical': [(36, 32.6), (68.5, 47.4), (110.5, 58.9), (132.1, 57), (163.7, 60)],
    'cybersecurity': [(29.8, 90.3), (58.5, 91.2), (86.2, 92.0), (113.8, 93.6), (141.3, 93.4)],
    'gray': [(88.4, 81.1), (112.6, 83.5), (81.1, 98.2)],
    'black': [(104.7, 76.1), (133, 75.8), (116.5, 96.4)]
}

data_llama = {
    'geographic': [(61.1, 14.7), (71.3, 22.1), (106.9, 27.4), (142.9, 33.7), (179.7, 34.7)],
    'medical': [(66.6, 42.1), (87.4, 52.6), (127.5, 55.8), (168.4, 58.9), (210.9, 56.8)],
    'cybersecurity': [(54.9, 70.8), (75.1, 74.3), (111.6, 76.1), (147.8, 75.2), (184.5, 75.2)],
    'gray': [(53.3, 81.7), (77.8, 72.7), (68, 92)],
    'black': [(74.8, 58.7), (95.6 , 72.9), (103.8, 96.9)]
}

# Create a figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(8, 4), sharey=True)

# Plot for the default model
for ax, (model_name, data) in zip(axes, [('GPT-4o', data_default), ('LLaMA 3.2-8B', data_llama)]):
    for i, (dataset, points) in enumerate(data.items()):
        if dataset == 'gray':
            # Plot each baseline point with its respective color
            for j, baseline_point in enumerate(points):
                ax.plot(baseline_point[0], baseline_point[1], marker='*', color=colors[j], markersize=14)
            # Add only one legend entry for the baseline
            ax.plot([], [], marker='*', color=colors[3], markersize=14, label='Aware')
        elif dataset == 'black':
            # Plot each baseline point with its respective color
            for j, baseline_point in enumerate(points):
                ax.plot(baseline_point[0], baseline_point[1], marker='*', markerfacecolor='none',color=colors[j], markersize=14)
            # Add only one legend entry for the baseline
            ax.plot([], [], marker='*', color=colors[3], markerfacecolor='none',markersize=14, label='Agonistic')
        else:
            ax.plot([p[0] for p in points], [p[1] for p in points], marker='o', color=colors[i], label=dataset.capitalize())

    ax.set_title(model_name, fontweight='bold')
    ax.set_xlabel('Token Consumption', fontweight='bold')
    ax.grid(True, linestyle='--')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(True)
    ax.tick_params(axis='y', length=0)

axes[0].set_ylabel('ASR (%)', fontweight='bold')
axes[0].legend()

# Adjust layout
plt.tight_layout()
plt.savefig('token_comsumption.pdf')

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set Seaborn style
sns.set_theme(style="whitegrid")
plt.rcParams['font.family'] = 'Optima'
plt.rcParams['font.weight'] = 'bold'

# Define colors
colors = sns.color_palette("muted")

# Data for the first set of plots
data_default = {
    'geographic': [(32, 34.7), (62.7, 52.6), (99.6, 53.7), (122.1, 60), (152.1, 61.3)],
    'medical': [(36, 32.6), (68.5, 47.4), (110.5, 58.9), (132.1, 57), (163.7, 60)],
    'cybersecurity': [(29.8, 90.3), (58.5, 91.2), (86.2, 92.0), (113.8, 93.6), (141.3, 93.4)],
    'gray': [(88.4, 81.1), (112.6, 83.5), (81.1, 98.2)],
    'black': [(104.7, 76.1), (133, 75.8), (116.5, 96.4)]
}

data_llama = {
    'geographic': [(61.1, 14.7), (71.3, 22.1), (106.9, 27.4), (142.9, 33.7), (179.7, 34.7)],
    'medical': [(66.6, 42.1), (87.4, 52.6), (127.5, 55.8), (168.4, 58.9), (210.9, 56.8)],
    'cybersecurity': [(54.9, 70.8), (75.1, 74.3), (111.6, 76.1), (147.8, 75.2), (184.5, 75.2)],
    'gray': [(53.3, 81.7), (77.8, 72.7), (68, 92)],
    'black': [(74.8, 58.7), (95.6 , 72.9), (103.8, 96.9)]
}

# Data for the second set of plots
x = [0, 1, 3, 5, 10]

data1 = [[[1, 72.6], [3, 81.1], [5, 80.6], [10, 82.6]],
         [[1, 75.7], [3, 83.5], [5, 83.5], [10, 82.3]],
         [[1, 97.3], [3, 98.2], [5, 98.7], [10, 98.2]]]

data3 = [[[0, 23.2], [1, 57.9], [3, 65.3], [5, 81.1], [10, 82.7]],
         [[0, 28.2], [1, 63.1], [3, 68.9], [5, 83.5], [10, 84.8]],
         [[0, 29.2], [1, 91.2], [3, 95.6], [5, 98.2], [10, 98.7]]]

data4 = [[[1, 81.1], [3, 74.7], [5, 76.8], [10, 75.8]],
         [[1, 83.5], [3, 82.5], [5, 81.6], [10, 84.5]],
         [[1, 98.2], [3, 94.7], [5, 97.3], [10, 92.0]]]

data_full = [data1, data3, data4]

# Create a figure with five subplots
fig, axes = plt.subplots(1, 5, figsize=(20, 4))

# Plot for the default and llama models
for ax, (model_name, data) in zip(axes[:2], [('GPT-4o', data_default), ('LLaMA 3.2-8B', data_llama)]):
    for i, (dataset, points) in enumerate(data.items()):
        if dataset == 'gray':
            for j, baseline_point in enumerate(points):
                ax.plot(baseline_point[0], baseline_point[1], marker='*', color=colors[j], markersize=14)
            ax.plot([], [], marker='*', color=colors[3], markersize=14, label='Aware')
        elif dataset == 'black':
            for j, baseline_point in enumerate(points):
                ax.plot(baseline_point[0], baseline_point[1], marker='*', markerfacecolor='none', color=colors[j], markersize=14)
            ax.plot([], [], marker='*', color=colors[3], markerfacecolor='none', markersize=14, label='Agnostic')
        else:
            ax.plot([p[0] for p in points], [p[1] for p in points], marker='o', color=colors[i], label=dataset.capitalize())

    ax.set_title(model_name, fontweight='bold')
    ax.set_xlabel('Token Consumption', fontweight='bold')
    ax.grid(True, linestyle='--')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(True)
    ax.tick_params(axis='y', length=0)

axes[0].set_ylabel('ASR (%)', fontweight='bold')
axes[0].legend(ncol=2)

# Set y-limits for the first two subplots
for ax in axes[:2]:
    ax.set_ylim(10, 103)  # Adjust this range as needed
    # ax.set_xlim(25, 220)  # Adjust this range as needed

# Plot for the ablation study
x_labels = [
    r'$N_\alpha$ of corpus generation in Relation Replacement',
    r'$|V_{r,n}^{l}|$ in Relation Enhancement',
    'Number of Text Replications'
]

x_tick_labels = [
    ['0', '1', '3', '5', '10'],
    ['0', '1', '3', '5', '10'],
    ['0', '1', '3', '5', '10'],
]

for i, ax in enumerate(axes[2:]):
    ax.plot([d[0] for d in data_full[i][0]], [d[1] for d in data_full[i][0]], marker='o', color=colors[0], label='Geographic')
    ax.plot([d[0] for d in data_full[i][1]], [d[1] for d in data_full[i][1]], marker='o', color=colors[1], label='Medical')
    ax.plot([d[0] for d in data_full[i][2]], [d[1] for d in data_full[i][2]], marker='o', color=colors[2], label='Cybersecurity')

    ax.set_xlabel(x_labels[i], fontweight='bold')
    if i == 0:
        ax.set_ylabel('ASR(%)', fontweight='bold')
    ax.set_xticks(x)
    ax.set_xticklabels(x_tick_labels[i])
    if i == 0:
        ax.legend(loc='lower right')
    ax.grid(True, linestyle='--')
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(True)
    
    ax.tick_params(axis='y', length=0)

# Set y-limits for the last three subplots
for ax in axes[2:]:
    ax.set_ylim(20, 100)  # Adjust this range as needed
# Hide y-tick labels for specific subplots
for ax in [axes[1], axes[3], axes[4]]:
    ax.set_yticklabels([])  # Hide y-tick labels

# Adjust layout
plt.tight_layout()
# plt.subplots_adjust(wspace=0.17)
plt.savefig('combined_plots.pdf')

# Show plot
plt.show()

# %%
import matplotlib.font_manager as fm

# 列出所有可用字体
available_fonts = [f.name.lower() for f in fm.fontManager.ttflist]
print("Available fonts:", available_fonts)

# 检查 Optima 是否在可用字体中
if 'optima' in available_fonts:
    print("Optima font is available.")
else:
    print("Optima font is not available.")
# Out:
# Available fonts: ['dejavu serif', 'stixsizefoursym', 'dejavu sans', 'stixsizefoursym', 'stixsizeonesym', 'dejavu serif', 'stixsizethreesym', 'cmex10', 'cmr10', 'stixgeneral', 'dejavu serif', 'stixsizetwosym', 'dejavu sans', 'dejavu sans mono', 'stixgeneral', 'dejavu sans mono', 'cmb10', 'cmsy10', 'stixsizetwosym', 'cmtt10', 'dejavu serif', 'stixsizefivesym', 'dejavu sans', 'dejavu sans display', 'stixsizethreesym', 'stixgeneral', 'stixnonunicode', 'dejavu sans', 'cmss10', 'stixgeneral', 'stixsizeonesym', 'stixnonunicode', 'stixnonunicode', 'dejavu sans mono', 'stixnonunicode', 'dejavu sans mono', 'dejavu serif display', 'cmmi10', 'norasi', 'urw bookman', 'loma', 'waree', 'mitra ', 'z003', 'freemono', 'msam10', 'dejavu sans mono', 'garuda', 'loma', 'mathjax_typewriter', 'lato', 'mathjax_winchrome', 'laksaman', 'sawasdee', 'laksaman', 'umpush', 'freeserif', 'eufm10', 'nimbus sans', 'gidugu', 'mathjax_fraktur', 'kinnari', 'nimbus mono ps', 'padmaa', 'nimbus sans narrow', 'tlwg typo', 'potti sreeramulu', 'urw bookman', 'liberation serif', 'sawasdee', 'nimbus sans', 'urw gothic', 'chandas', 'norasi', 'liberation mono', 'yrsa', 'dyuthi', 'urw bookman', 'raghumalayalamsans', 'yrsa', 'manjari', 'ubuntu', 'manjari', 'mathjax_vector', 'nimbus sans narrow', 'kacstpen', 'yrsa', 'rasa', 'tlwg typist', 'kinnari', 'liberation mono', 'sree krushnadevaraya', 'garuda', 'rachana', 'ramabhadra', 'liberation sans', 'gayathri', 'mukti', 'padauk book', 'liberation serif', 'dejavu sans', 'dsrom10', 'lato', 'uroob', 'dejavu sans', 'purisa', 'liberation sans', 'kacstoffice', 'nimbus roman', 'stmary10', 'urw gothic', 'lato', 'mukti', 'c059', 'sarai', 'nakula', 'kinnari', 'ori1uni', 'urw gothic', 'lato', 'rasa', 'optima', 'ubuntu', 'liberation sans', 'tlwg mono', 'optima', 'noto serif cjk jp', 'lato', 'tenaliramakrishna', 'c059', 'chilanka', 'lato', 'lohit malayalam', 'droid sans fallback', 'liberation sans narrow', 'umpush', 'liberation serif', 'lato', 'liberation sans narrow', 'tlwg mono', 'mathjax_size1', 'rekha', 'rasa', 'padmaa-bold.1.1', 'mry_kacstqurn', 'dejavu serif', 'freesans', 'd050000l', 'lato', 'mathjax_vector-bold', 'lato', 'wasy10', 'dejavu sans', 'ubuntu', 'mathjax_math', 'jamrul', 'lklug', 'sawasdee', 'aakar', 'umpush', 'umpush', 'mathjax_size3', 'mathjax_caligraphic', 'tlwg mono', 'yrsa', 'freesans', 'syamala ramana', 'yrsa', 'meera', 'liberation mono', 'dejavu serif', 'mandali', 'liberation mono', 'optima', 'noto sans cjk jp', 'norasi', 'laksaman', 'optima', 'liberation sans narrow', 'dejavu sans', 'mathjax_sansserif', 'mallanna', 'ubuntu', 'khmer os', 'rachana', 'lohit telugu', 'liberation sans', 'gurajada', 'kinnari', 'rasa', 'mathjax_fraktur', 'samanata', 'loma', 'kacstposter', 'ubuntu', 'ubuntu mono', 'lato', 'liberation sans', 'ubuntu condensed', 'urw gothic', 'mathjax_caligraphic', 'dejavu serif', 'tlwg typewriter', 'suranna', 'kacstone', 'dejavu sans mono', 'freemono', 'nimbus sans narrow', 'glyphicons halflings', 'liberation sans narrow', 'liberation serif', 'cmmi10', 'karumbi', 'norasi', 'kacstscreen', 'nimbus roman', 'nimbus sans narrow', 'lohit odia', 'liberation serif', 'manjari', 'liberation mono', 'tlwg typo', 'msbm10', 'lohit tamil', 'purisa', 'lohit bengali', 'lohit gujarati', 'kacstfarsi', 'lato', 'freemono', 'freesans', 'liberation mono', 'liberation mono', 'p052', 'dejavu sans', 'mathjax_size4', 'lato', 'padauk', 'dhurjati', 'noto sans cjk jp', 'nimbus roman', 'padauk', 'lohit devanagari', 'peddana', 'nimbus sans', 'lohit assamese', 'dejavu sans', 'freemono', 'dejavu serif', 'mathjax_sansserif', 'mathjax_script', 'lato', 'abyssinica sil', 'pothana2000', 'lohit kannada', 'likhan', 'noto sans mono', 'waree', 'mathjax_math', 'nimbus roman', 'ani', 'laksaman', 'lato', 'dejavu sans', 'c059', 'kacstletter', 'kalapi', 'esint10', 'gayathri', 'tlwg typist', 'yrsa', 'garuda', 'dejavu math tex gyre', 'tlwg typist', 'keraleeyam', 'cmsy10', 'samyak malayalam', 'mathjax_ams', 'vemana2000', 'dejavu serif', 'kacstart', 'padmaa', 'su ...
# Optima font is available.

# %%
y_data
# Out:
# [array([0.90852421, 0.56630876, 0.94493415, 0.59236972, 0.40613643]),
#  array([0.31231123, 1.92518436, 1.48368605, 1.19753001, 0.03353323]),
#  array([1.65971388, 2.36727204, 0.81224466, 1.19402746, 2.69387205]),
#  array([1.02833557, 3.38839963, 1.91310415, 0.44042888, 3.66056023])]
