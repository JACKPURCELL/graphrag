# %%
# !python -m graphrag.index --init --root ./ragtest5
# Out:
# Initializing project at ./ragtest3
# ⠋ GraphRAG Indexer

# %%
# !python -m graphrag.index --root ./ragtest5
# Out:
# 🚀 Reading settings from ragtest5/settings.yaml
# ⠹ GraphRAG Indexer
# ⠹ GraphRAG Indexer e.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# └── create_base_text_units
# ⠼ GraphRAG Indexer m╺━━━━━━━━━━━━━━━━━━━  50% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# /home/ljc/miniconda3/envs/fw/lib/python3.11/site-packages/numpy/core/fromnumeric
# .py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in
# a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# └── create_base_text_units
# 🚀 create_base_text_units━━   0% -:--:-- 0:00:00
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
#                                  id  ... n_tokens
# 0  f93ee0525fade38778aac92dced33cf7  ...      347
# 1  d8da4a1c8ad49468ac59cbf6d7810029  ...      807
#
# [2 rows x 5 columns]
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠴ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠧ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:01
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠋ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:02
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠹ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:03
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠴ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:04
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠇ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:05
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠋ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:06
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠸ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:07
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠴ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:08
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠇ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:09
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠙ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:10
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠸ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:11
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠦ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:12
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠇ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:13
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠙ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:14
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠼ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:15
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠦ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:16
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠏ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:17
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠙ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:18
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠼ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:19
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠧ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:20
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠏ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:21
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠹ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:22
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠼ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:23
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠧ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:24
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠋ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:25
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠹ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:26
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠋ GraphRAG Indexer 1m╸━━━━━━━━━━━━━━━  50% -:--:-- 0:00:27
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# 🚀 create_base_extracted_entities
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
#                                         entity_graph
# 0  <graphml xmlns="http://graphml.graphdrawing.or...
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠧ GraphRAG Indexer ╸  98% 0:00:01 0:00:00
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠋ GraphRAG Indexer ╸  98% 0:00:01 0:00:01
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# 🚀 create_summarized_entities
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
#                                         entity_graph
# 0  <graphml xmlns="http://graphml.graphdrawing.or...
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# 🚀 create_base_entity_graph
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
#    level  ...                                         embeddings
# 0      0  ...  {'2024 SUMMER OLYMPICS': [0.001094804960303008...
#
# [1 rows x 3 columns]
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# /home/ljc/miniconda3/envs/fw/lib/python3.11/site-packages/numpy/core/fromnumeric
# .py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in
# a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠦ GraphRAG Indexer  -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠙ GraphRAG Indexer  -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠸ GraphRAG Indexer ━━━  33% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠸ GraphRAG Indexer ━━━  67% 0:00:01 0:00:00
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# /home/ljc/miniconda3/envs/fw/lib/python3.11/site-packages/numpy/core/fromnumeric
# .py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in
# a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# 🚀 create_final_entities-- 0:00:00
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
#                                   id  ...
# description_embedding
# 0   b45241d70f0e43fca764df95b2b81f77  ...  [0.010459105484187603,
# -0.021651852875947952, ...
# 1   4119fd06010c494caa07f439b333f4c5  ...  [0.029967838898301125,
# -0.023047208786010742, ...
# 2   d3835bf3dda84ead99deadbeac5d0d7d  ...  [0.021040860563516617,
# -0.03102407604455948, 0...
# 3   077d2820ae1845bcbb1803379a3d1eae  ...  [0.0008975855889730155,
# -0.01783186011016369, ...
# 4   3671ea0dd4e84c1a9b02c5ab2c8f4bac  ...  [0.008606916293501854,
# -0.0097848204895854, 0....
# 5   19a7f254a5d64566ab5cc15472df02de  ...  [0.00815639179199934,
# -0.051227133721113205, 0...
# 6   e7ffaee9d31d4d3c96e04f911d0a8f9e  ...  [0.03207431361079216,
# 0.00840067584067583, -0....
# 7   f7e11b0e297a44a896dc67928368f600  ...  [0.027697728946805,
# -0.03942489996552467, 0.06...
# 8   1fd3fa8bb5a2408790042ab9573779ee  ...  [0.020434753969311714,
# -0.02232402376830578, 0...
# 9   27f9fbe6ad8c4a8b9acee0d3596ed57c  ...  [0.028612880036234856,
# -0.04896637052297592, 0...
# 10  e1fd0e904a53409aada44442f23a51cb  ...  [0.0009896113770082593,
# -0.0346815288066864, 0...
# 11  de988724cfdf45cebfba3b13c43ceede  ...  [0.00491019431501627,
# -0.06393028795719147, 0....
# 12  96aad7cb4b7d40e9b7e13b94a67af206  ...  [0.014571747742593288,
# 0.0086422860622406, 0.0...
# 13  c9632a35146940c2a86167c7726d35e9  ...  [0.024945011362433434,
# 0.007369674742221832, -...
# 14  9646481f66ce4fd2b08c2eddda42fc82  ...  [0.0037032573018223047,
# 0.021884575486183167, ...
# 15  d91a266f766b4737a06b0fda588ba40b  ...  [0.010539108887314796,
# -0.020506203174591064, ...
# 16  bc0e3f075a4c4ebbb7c7b152b65a5625  ...  [-0.00992314051836729,
# 0.019040895625948906, -...
# 17  254770028d7a4fa9877da4ba0ad5ad21  ...  [-0.019482802599668503,
# 0.007996453903615475, ...
# 18  4a67211867e5464ba45126315a122a8a  ...  [-0.007857033051550388,
# -0.0163373164832592, 0...
# 19  04dbbb2283b845baaeac0eaf0c34c9da  ...  [0.004990255460143089,
# -0.03644975647330284, 0...
# 20  1943f245ee4243bdbfbd2fd619ae824a  ...  [-0.016283327713608742,
# 0.00991047639399767, -...
# 21  273daeec8cad41e6b3e450447db58ee7  ...  [-0.01637500710785389,
# -0.01725240983068943, 0...
# 22  e69dc259edb944ea9ea41264b9fcfe59  ...  [-0.004893730394542217,
# 0.05017101764678955, 0...
# 23  e2f5735c7d714423a2c4f61ca2644626  ...  [-0.015364577062427998,
# 0.00030296517070382833...
# 24  deece7e64b2a4628850d4bb6e394a9c3  ...  [-0.020868172869086266,
# -0.023112062364816666,...
# 25  e657b5121ff8456b9a610cfaead8e0cb  ...  [0.03056650608778,
# 0.009988420642912388, -0.03...
# 26  bf4e255cdac94ccc83a56435a5e4b075  ...  [0.01648307405412197,
# -0.04825699329376221, -0...
# 27  3b040bcc19f14e04880ae52881a89c1c  ...  [0.03717811778187752,
# 0.025621645152568817, 0....
# 28  3d6b216c14354332b1bf1927ba168986  ...  [-0.040576476603746414,
# -0.0012796481605619192...
# 29  1c109cfdc370463eb6d537e5b7b382fb  ...  [-0.045607224106788635,
# -0.019947832450270653,...
# 30  3d0dcbc8971b415ea18065edc4d8c8ef  ...  [-0.017228977754712105,
# -0.004823458380997181,...
# 31  68105770b523412388424d984e711917  ...  [0.014830664731562138,
# -0.00385306472890079, 0...
# 32  85c79fd84f5e4f918471c386852204c5  ...  [-0.02524159848690033,
# -0.009328696876764297, ...
#
# [33 rows x 8 columns]
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠦ GraphRAG Indexer m-:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠇ GraphRAG Indexer m-:--:-- 0:00:01
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠙ GraphRAG Indexer m-:--:-- 0:00:02
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠼ GraphRAG Indexer m-:--:-- 0:00:03
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠦ GraphRAG Indexer m-:--:-- 0:00:04
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# /home/ljc/miniconda3/envs/fw/lib/python3.11/site-packages/numpy/core/fromnumeric
# .py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in
# a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠧ GraphRAG Indexer m-:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# /home/ljc/miniconda3/envs/fw/lib/python3.11/site-packages/datashaper/engine/verb
# s/convert.py:72: FutureWarning: errors='ignore' is deprecated and will raise in
# a future version. Use to_datetime without passing `errors` and catch exceptions
# explicitly instead
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# /home/ljc/miniconda3/envs/fw/lib/python3.11/site-packages/datashaper/engine/verb
# s/convert.py:72: UserWarning: Could not infer format, so each element will be
# parsed individually, falling back to `dateutil`. To ensure parsing is consistent
# and as-expected, please specify a format.
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠇ GraphRAG Indexer m-:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# 🚀 create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
#     level                                      title  ...          x          y
# 0       0                                      PARIS  ...  -9.581524  -4.546367
# 1       0                                     FRANCE  ...  -9.730058  -3.963513
# 2       0                                    SEATTLE  ...  -8.834587  -4.741928
# 3       0                               SPACE NEEDLE  ...  -1.442762  -4.240273
# 4       0                   CHIHULY GARDEN AND GLASS  ...  -7.981055  -2.560910
# 5       0                          PIKE PLACE MARKET  ...  -5.308868  -7.305455
# 6       0                      MUSEUM OF POP CULTURE  ...  -2.813854  -3.052166
# 7       0                         SEATTLE ART MUSEUM  ...  -9.434274  -2.813115
# 8       0                         SEATTLE WATERFRONT  ... -10.207968  -3.181549
# 9       0                             DISCOVERY PARK  ...  -5.728736  -2.666645
# 10      0                          BAINBRIDGE ISLAND  ...  -2.982808  -5.584923
# 11      0                              FREMONT TROLL  ...  -4.311757  -5.518789
# 12      0                              BALLARD LOCKS  ...  -1.926204  -4.902334
# 13      0                              ÎLE-DE-FRANCE  ...  -6.069588  -6.798619
# 14      0                  CHARLES DE GAULLE AIRPORT  ...  -0.524138  13.932033
# 15      0                               ORLY AIRPORT  ...  -5.790582  -5.905490
# 16      0                                PARIS MÉTRO  ...  -3.310377  -6.376878
# 17      0                                     LOUVRE  ...  -3.305482  -1.768542
# 18      0                                     UNESCO  ...  -2.047186  -3.457872
# 19      0                        PARIS SAINT-GERMAIN  ...  -2.658609  -2.014762
# 20      0                             STADE FRANÇAIS  ...   0.314045  14.347342
# 21      0                            STADE DE FRANCE  ...  -4.951521  -6.110037
# 22      0                                FRENCH OPEN  ...  -5.285951  -5.210172
# 23      0                       2024 SUMMER OLYMPICS  ...  -8.700691  -2.321249
# 24      0                              MUSÉE D'ORSAY  ...  -0.652744  14.939609
# 25      0                                MUSÉE RODIN  ...  -0.070230  15.501422
# 26      0                              MUSÉE PICASSO  ...  -7.098849  -1.960718
# 27      0                                      SEINE  ...  -2.225826  -6.008890
# 28      0                      EUROPEAN SPACE AGENCY  ...   0.414044  15.090023
# 29      0                 EUROPEAN BANKING AUTHORITY  ...  -3.742993  -2.520090
# 30      0  EUROPEAN SECURITIES AND MARKETS AUTHORITY  ...  -8.763649  -3.436853
# 31      0                               GARE DU NORD  ...  -5.944658  -1.802230
# 32      0                            POMPIDOU CENTRE  ...  -5.138498  -2.201330
#
# [33 rows x 15 columns]
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# /home/ljc/miniconda3/envs/fw/lib/python3.11/site-packages/numpy/core/fromnumeric
# .py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in
# a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# └── create_final_communities
# ⠙ GraphRAG Indexer  0:00:00
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# /home/ljc/miniconda3/envs/fw/lib/python3.11/site-packages/numpy/core/fromnumeric
# .py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in
# a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# └── create_final_communities
# ⠹ GraphRAG Indexer  0:00:00
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# 🚀 create_final_communities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
#   id  ...                                      text_unit_ids
# 0  0  ...  [d8da4a1c8ad49468ac59cbf6d7810029,f93ee0525fad...
# 1  1  ...
#
# [2 rows x 6 columns]
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# 🚀 join_text_units_to_entity_ids
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
#                       text_unit_ids  ...                                id
# 0  d8da4a1c8ad49468ac59cbf6d7810029  ...  d8da4a1c8ad49468ac59cbf6d7810029
# 1  f93ee0525fade38778aac92dced33cf7  ...  f93ee0525fade38778aac92dced33cf7
#
# [2 rows x 3 columns]
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# /home/ljc/miniconda3/envs/fw/lib/python3.11/site-packages/numpy/core/fromnumeric
# .py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in
# a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# └── create_final_relationships
# ⠇ GraphRAG Indexer 0
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# /home/ljc/miniconda3/envs/fw/lib/python3.11/site-packages/numpy/core/fromnumeric
# .py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in
# a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# └── create_final_relationships
# ⠏ GraphRAG Indexer 0
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# /home/ljc/miniconda3/envs/fw/lib/python3.11/site-packages/datashaper/engine/verb
# s/convert.py:65: FutureWarning: errors='ignore' is deprecated and will raise in
# a future version. Use to_numeric without passing `errors` and catch exceptions
# explicitly instead
#   column_numeric = cast(pd.Series, pd.to_numeric(column, errors="ignore"))
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# └── create_final_relationships
# ⠏ GraphRAG Indexer 0
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# 🚀 create_final_relationships
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
#      source                                     target  ...  target_degree rank
# 0     PARIS                                     FRANCE  ...              2   23
# 1     PARIS                              ÎLE-DE-FRANCE  ...              1   22
# 2     PARIS                  CHARLES DE GAULLE AIRPORT  ...              1   22
# 3     PARIS                               ORLY AIRPORT  ...              1   22
# 4     PARIS                                PARIS MÉTRO  ...              1   22
# 5     PARIS                                     LOUVRE  ...              1   22
# 6     PARIS                                     UNESCO  ...              1   22
# 7     PARIS                        PARIS SAINT-GERMAIN  ...              1   22
# 8     PARIS                             STADE FRANÇAIS  ...              1   22
# 9     PARIS                            STADE DE FRANCE  ...              1   22
# 10    PARIS                                FRENCH OPEN  ...              1   22
# 11    PARIS                       2024 SUMMER OLYMPICS  ...              1   22
# 12    PARIS                               GARE DU NORD  ...              1   22
# 13    PARIS                              MUSÉE D'ORSAY  ...              1   22
# 14    PARIS                                MUSÉE RODIN  ...              1   22
# 15    PARIS                              MUSÉE PICASSO  ...              1   22
# 16    PARIS                            POMPIDOU CENTRE  ...              1   22
# 17    PARIS                                      SEINE  ...              1   22
# 18    PARIS                      EUROPEAN SPACE AGENCY  ...              1   22
# 19    PARIS                 EUROPEAN BANKING AUTHORITY  ...              1   22
# 20    PARIS  EUROPEAN SECURITIES AND MARKETS AUTHORITY  ...              1   22
# 21   FRANCE                                    SEATTLE  ...             11   13
# 22  SEATTLE                               SPACE NEEDLE  ...              1   12
# 23  SEATTLE                   CHIHULY GARDEN AND GLASS  ...              1   12
# 24  SEATTLE                          PIKE PLACE MARKET  ...              1   12
# 25  SEATTLE                      MUSEUM OF POP CULTURE  ...              1   12
# 26  SEATTLE                         SEATTLE ART MUSEUM  ...              1   12
# 27  SEATTLE                         SEATTLE WATERFRONT  ...              1   12
# 28  SEATTLE                             DISCOVERY PARK  ...              1   12
# 29  SEATTLE                          BAINBRIDGE ISLAND  ...              1   12
# 30  SEATTLE                              FREMONT TROLL  ...              1   12
# 31  SEATTLE                              BALLARD LOCKS  ...              1   12
#
# [32 rows x 10 columns]
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ⠹ GraphRAG Indexer
# ...
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# 🚀 create_final_community_reports
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
#   community  ...                                    id
# 0         0  ...  fd907504-a58d-41f1-885a-043b5e6d6db9
# 1         1  ...  98230751-920e-424b-9b70-e2e85502542f
#
# [2 rows x 10 columns]
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# 🚀 create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
#                                  id  ...
# relationship_ids
# 0  f93ee0525fade38778aac92dced33cf7  ...  [eae4259b19a741ab9f9f6af18c4a0470,
# 2670deebfa3...
# 1  d8da4a1c8ad49468ac59cbf6d7810029  ...  [3138f39f2bcd43a69e0697cd3b05bc4d,
# dde131ab575...
#
# [2 rows x 6 columns]
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# /home/ljc/miniconda3/envs/fw/lib/python3.11/site-packages/datashaper/engine/verb
# s/convert.py:72: FutureWarning: errors='ignore' is deprecated and will raise in
# a future version. Use to_datetime without passing `errors` and catch exceptions
# explicitly instead
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# └── create_base_documents
# /home/ljc/miniconda3/envs/fw/lib/python3.11/site-packages/datashaper/engine/verb
# s/convert.py:72: UserWarning: Could not infer format, so each element will be
# parsed individually, falling back to `dateutil`. To ensure parsing is consistent
# and as-expected, please specify a format.
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# └── create_base_documents
# 🚀 create_base_documents
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
#                                  id  ...  title
# 0  b8fcd5cdfafc666d552e9f5f6bf7065a  ...  a.txt
# 1  ba6263607ce5f62cf816dbcae0ba0e88  ...  b.txt
#
# [2 rows x 4 columns]
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
# 🚀 create_final_documents
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
#                                  id  ...  title
# 0  b8fcd5cdfafc666d552e9f5f6bf7065a  ...  a.txt
# 1  ba6263607ce5f62cf816dbcae0ba0e88  ...  b.txt
#
# [2 rows x 4 columns]
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 2 files loaded (0 filtered) ━ 100% … 0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
# └── create_final_documents
# 🚀 All workflows completed successfully.

# %%
import os
import glob
import networkx as nx
import matplotlib.pyplot as plt

# 步骤 1：找到排序最大的文件夹
output_path = '/home/ljc/graphrag/ragtest5/output'
folders = [os.path.join(output_path, d) for d in os.listdir(output_path) if os.path.isdir(os.path.join(output_path, d))]
latest_folder = max(folders, key=os.path.getmtime)

# 步骤 2：找到该文件夹下的 artifacts/merged_graph.graphml 文件
graphml_file_path = os.path.join(latest_folder, 'artifacts', 'merged_graph.graphml')

# 检查文件是否存在
if not os.path.isfile(graphml_file_path):
    print(f"GraphML 文件未找到: {graphml_file_path}")
else:
    # 步骤 3：读取 GraphML 文件并进行可视化
    graph = nx.read_graphml(graphml_file_path)
    
    # 绘制图形
    plt.figure(figsize=(15, 15))
    pos = nx.spring_layout(graph)  # 使用 spring layout 布局
    nx.draw(graph, pos, with_labels=True, node_size=500, node_color='skyblue', font_size=10, font_weight='regular', edge_color='gray')
    plt.title('GraphML Visualization')
    plt.show()

# %%
# !python -m graphrag.query --root ./ragtest5 --method local \
    "Please help me plan my trip to the capital of France"
# Out:
# INFO: Reading settings from ragtest5/settings.yaml
#
# INFO: Vector Store Args: {}
# creating llm client with {'api_key': 'REDACTED,len=56', 'type': "openai_chat", 'model': 'gpt-4o-mini', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': None, 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
# creating embedding llm client with {'api_key': 'REDACTED,len=56', 'type': "openai_embedding", 'model': 'text-embedding-3-small', 'max_tokens': 4000, 'temperature': 0, 'top_p': 1, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': None, 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': None, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
# =========context_data=========
#
# {'reports':   id  ...                                            content
# 0  0  ...  # Paris: A Hub of Culture, Sports, and Finance...
# 1  0  ...  # Paris: A Hub of Culture, Sports, and Finance...
#
# [2 rows x 3 columns], 'relationships':     id   source  ... links in_context
# 0    0    PARIS  ...     1       True
# 1    1    PARIS  ...     1       True
# 2    2    PARIS  ...     1       True
# 3    3    PARIS  ...     1       True
# 4    4    PARIS  ...     1       True
# 5    5    PARIS  ...     1       True
# 6    7    PARIS  ...     1       True
# 7    8    PARIS  ...     1       True
# 8    9    PARIS  ...     1       True
# 9   10    PARIS  ...     1       True
# 10  11    PARIS  ...     1       True
# 11  12    PARIS  ...     1       True
# 12  13    PARIS  ...     1       True
# 13  14    PARIS  ...     1       True
# 14  15    PARIS  ...     1       True
# 15  16    PARIS  ...     1       True
# 16  17    PARIS  ...     1       True
# 17  18    PARIS  ...     1       True
# 18  21   FRANCE  ...     1       True
# 19   6    PARIS  ...     1       True
# 20  19    PARIS  ...     1       True
# 21  20    PARIS  ...     1       True
# 22  22  SEATTLE  ...     1       True
# 23  23  SEATTLE  ...     1       True
# 24  24  SEATTLE  ...     1       True
# 25  25  SEATTLE  ...     1       True
# 26  26  SEATTLE  ...     1       True
# 27  27  SEATTLE  ...     1       True
# 28  28  SEATTLE  ...     1       True
# 29  29  SEATTLE  ...     1       True
# 30  30  SEATTLE  ...     1       True
# 31  31  SEATTLE  ...     1       True
#
# [32 rows x 8 columns], 'claims': Empty DataFrame
# Columns: [in_context]
# Index: [], 'entities':     id                     entity  ... number of relationships in_context
# 0    0                      PARIS  ...                      21       True
# 1    1                     FRANCE  ...                       2       True
# 2   15               ORLY AIRPORT  ...                       1       True
# 3   32            POMPIDOU CENTRE  ...                       1       True
# 4   13              ÎLE-DE-FRANCE  ...                       1       True
# 5   21            STADE DE FRANCE  ...                       1       True
# 6   16                PARIS MÉTRO  ...                       1       True
# 7   17                     LOUVRE  ...                       1       True
# 8   14  CHARLES DE GAULLE AIRPORT  ...                       1       True
# 9   27                      SEINE  ...                       1       True
# 10  20             STADE FRANÇAIS  ...                       1       True
# 11  23       2024 SUMMER OLYMPICS  ...                       1       True
# 12  24              MUSÉE D'ORSAY  ...                       1       True
# 13  22                FRENCH OPEN  ...                       1       True
# 14   2                    SEATTLE  ...                      11       True
# 15  19        PARIS SAINT-GERMAIN  ...                       1       True
# 16  31               GARE DU NORD  ...                       1       True
# 17  25                MUSÉE RODIN  ...                       1       True
# 18  28      EUROPEAN SPACE AGENCY  ...                       1       True
# 19  26              MUSÉE PICASSO  ...                       1       True
#
# [20 rows x 5 columns], 'sources':   id                                               text
# 0  1   With an official estimated population of 2,10...
# 1  0  Paris is the capital of France before. In an a...}
#
# SUCCESS: Local Search Response: # Planning Your Trip to Paris, the Capital of France
#
# Paris, known as the City of Light, is a vibrant metropolis rich in culture, history, and art. As the capital of France, it offers a plethora of attractions and experiences that cater to all types of travelers. Here’s a guide to help you plan your trip effectively.
#
# ## Key Attractions
#
# ### Cultural Landmarks
# Paris is home to some of the most famous cultural institutions in the world. The **Louvre**, the most-visited art museum globally, showcases an extensive collection of art, including the Mona Lisa. The **Musée d'Orsay** is renowned for its Impressionist masterpieces, while the **Pompidou Centre** features modern art collections and striking architecture [Data: Entities (17, 24, 32); Relationships (5, 13, 16)].
#
# ### Historical Sites
# The **Seine River** runs through the heart of Paris, offering scenic views and historical significance. You can enjoy a leisurely stroll along its banks or take a boat tour to see the city from a different perspective [Data: Entities (27); Relationships (17)]. Additionally, the **Notre-Dame Cathedral** and the **Eiffel Tower** are must-visit landmarks that embody the city's rich history and architectural beauty.
#
# ## Upcoming Events
#
# ### 2024 Summer Olympics
# One of the most significant events on the horizon is the **2024 Summer Olympics**, which will attract visitors from around the world. This event is expected to enhance Paris's international profile and boost tourism, making it an exciting time to visit [Data: Entities (23); Relationships (11)].
#
# ## Transportation
#
# ### Airports
# Paris is served by two major international airports: **Charles de Gaulle Airport** and **Orly Airport**. Both airports facilitate millions of passengers each year and are crucial for connecting Paris to the rest of the world [Data: Entities (14, 15); Relationships (2, 3)].
#
# ### Public Transport
# The **Paris Métro** is an efficient subway system that serves over 5 million passengers daily, making it easy to navigate the city [Data: Entities (16); Relationships (4)]. Additionally, the **Gare du Nord** is a key railway station for domestic and international travel, enhancing connectivity [Data: Relationships (12)].
#
# ## Sports and Recreation
#
# ### Local Sports Culture
# Paris boasts a vibrant sports culture, with clubs like **Paris Saint-Germain** and **Stade Français** representing the city in football and rugby, respectively. The **Stade de France**, located just north of the city, is a significant venue for various sporting events, including the upcoming Olympics [Data: Entities (19, 20, 21); Relationships (7, 8, 9)].
#
# ## Conclusion
#
# Paris is a city that beautifully blends history, culture, and modernity. Whether you're exploring its world-class museums, enjoying the scenic views along the Seine, or preparing for the excitement of the 2024 Summer Olympics, there’s something for everyone. Make sure to plan your itinerary to include these highlights, and enjoy your trip to the enchanting capital of France!
