# %%
# !python -m graphrag.index --init --root ./ragtest6
# Out:
# Initializing project at ./ragtest6
# ⠋ GraphRAG Indexer

# %%
# !python -m graphrag.index --root ./ragtest6
# Out:
# Logging enabled at ragtest6/output/20240903-120120/reports/indexing-engine.log
# ⠸ GraphRAG Indexer
# ⠸ GraphRAG Indexer e.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# └── create_base_text_units
# ⠴ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   7% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# └── create_base_text_units
# 🚀 create_base_text_units━━   0% -:--:-- 0:00:00
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
#                                   id  ... n_tokens
# 0   cc0dbbd456ec94f96f25793657991734  ...      669
# 1   b324dfcc8a3699591c60646ccaf6e4b0  ...     1035
# 2   c796265ad38bbdc79dc17b2d0aba7e9e  ...      746
# 3   e201254a65d111262b3361be30dbaa31  ...      621
# 4   7f6347c263ce28650c650f3f050a4f70  ...      825
# 5   671f5b5587e9f72661c822748941b868  ...      661
# 6   2baa5d7f2a9844571079d991957cec9a  ...     1173
# 7   1bf396570d5a75e44626a2dbcb8cf10b  ...       73
# 8   1cf5059e2eced944286c9661bca717e2  ...      190
# 9   f791c070bd270519bbffc7dd4eb08b3a  ...      686
# 10  2feaa437afffb7674fa0506133b75626  ...      644
# 11  8375d3624fb8b896ff71ffc19d7f91cf  ...      794
# 12  cd0c2f9e8eaf3dddb95a58b3f5fdb8ef  ...      722
# 13  9c1159fac63a5f8b3069d98ad9224551  ...      603
# 14  acebe9382da99effdaf980d1072720f2  ...      875
# 15  aa86232b2bed138127746cc93ab4c0bc  ...      766
#
# [16 rows x 5 columns]
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# 🚀 create_base_extracted_entities
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
#                                         entity_graph
# 0  <graphml xmlns="http://graphml.graphdrawing.or...
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# 🚀 create_summarized_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
#                                         entity_graph
# 0  <graphml xmlns="http://graphml.graphdrawing.or...
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# └── create_base_entity_graph
# ⠦ GraphRAG Indexer ━━━━━━━━━━━  33% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# └── create_base_entity_graph
# ⠏ GraphRAG Indexer ━━━━━━━━━━━  33% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# └── create_base_entity_graph
# ⠴ GraphRAG Indexer ━━━━━━━━━━━  67% 0:00:01 0:00:00
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# 🚀 create_base_entity_graph
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
#    level  ...                                         embeddings
# 0      0  ...  {'1906 EARTHQUAKE AND FIRE': [-0.0499169826507...
# 1      1  ...  {'1906 EARTHQUAKE AND FIRE': [-0.0517604984343...
# 2      2  ...  {'1906 EARTHQUAKE AND FIRE': [-0.0494911707937...
#
# [3 rows x 3 columns]
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠼ GraphRAG Indexer  -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠧ GraphRAG Indexer ━━━  42% 0:00:01 0:00:00
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# 🚀 create_final_entities-- 0:00:00
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
#                                    id  ...
# description_embedding
# 0    b45241d70f0e43fca764df95b2b81f77  ...  [0.015677249059081078,
# -0.0008531556813977659,...
# 1    4119fd06010c494caa07f439b333f4c5  ...  [0.022973792627453804,
# 0.00818716362118721, 0....
# 2    d3835bf3dda84ead99deadbeac5d0d7d  ...  [-0.014571179635822773,
# -0.008761217817664146,...
# 3    077d2820ae1845bcbb1803379a3d1eae  ...  [-0.03513062000274658,
# 0.018098168075084686, 0...
# 4    3671ea0dd4e84c1a9b02c5ab2c8f4bac  ...  [-0.023570645600557327,
# -0.03967861086130142, ...
# ..                                ...  ...
# ...
# 146  ba481175ee1d4329bf07757a30abd3a1  ...  [-0.012510384432971478,
# -0.014354996383190155,...
# 147  8d8da35190bf43c5878fa38f3eb4f3d2  ...  [0.020752426236867905,
# 0.00478208065032959, 0....
# 148  2fb7e14a3f124526bd7b24867fc18e81  ...  [0.05169956758618355,
# 0.02471093274652958, -0....
# 149  5c13c7d61e6c4bfe839f21e7ad3530a7  ...  [0.014756258577108383,
# -0.008657949045300484, ...
# 150  a621663edba64d99b7e50f1e53f32ee7  ...  [0.03451194614171982,
# -0.008943959139287472, 0...
#
# [302 rows x 8 columns]
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numba/np/ufun
# c/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version
# 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found
# TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠼ GraphRAG Indexer m-:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠧ GraphRAG Indexer m-:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠋ GraphRAG Indexer m-:--:-- 0:00:01
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠸ GraphRAG Indexer m-:--:-- 0:00:02
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠴ GraphRAG Indexer m-:--:-- 0:00:03
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠇ GraphRAG Indexer m-:--:-- 0:00:04
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠙ GraphRAG Indexer m-:--:-- 0:00:05
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠧ GraphRAG Indexer m-:--:-- 0:00:06
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠼ GraphRAG Indexer  33% -:--:-- 0:00:06
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠴ GraphRAG Indexer  33% -:--:-- 0:00:07
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠸ GraphRAG Indexer  67% 0:00:01 0:00:07
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠏ GraphRAG Indexer m-:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/datashaper/en
# gine/verbs/convert.py:72: FutureWarning: errors='ignore' is deprecated and will
# raise in a future version. Use to_datetime without passing `errors` and catch
# exceptions explicitly instead
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/datashaper/en
# gine/verbs/convert.py:72: UserWarning: Could not infer format, so each element
# will be parsed individually, falling back to `dateutil`. To ensure parsing is
# consistent and as-expected, please specify a format.
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠋ GraphRAG Indexer m-:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# 🚀 create_final_nodes
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
#      level                     title  ...          x          y
# 0        0  UNITED STATES OF AMERICA  ...  27.067825  26.484116
# 1        0          WASHINGTON, D.C.  ...   9.129201  17.041071
# 2        0                    CANADA  ...  28.114258  27.530676
# 3        0                    MEXICO  ...  27.245827  26.662113
# 4        0                    ALASKA  ...  28.256557  27.673010
# ..     ...                       ...  ...        ...        ...
# 901      2                ALEXANDRIA  ...   9.681100  13.826219
# 902      2              PHILADELPHIA  ...   9.842430  13.959844
# 903      2    TWENTY-THIRD AMENDMENT  ...   8.969872  14.197742
# 904      2                  K STREET  ...   5.245308   7.808614
# 905      2      DISTRICT OF COLUMBIA  ...   9.363523  16.533430
#
# [906 rows x 15 columns]
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# └── create_final_communities
# ⠧ GraphRAG Indexer  0:00:00
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# └── create_final_communities
# ⠇ GraphRAG Indexer  0:00:00
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# 🚀 create_final_communities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
#     id  ...                                      text_unit_ids
# 0    8  ...  [cc0dbbd456ec94f96f25793657991734, aa86232b2be...
# 1   10  ...  [1cf5059e2eced944286c9661bca717e2,cc0dbbd456ec...
# 2    6  ...  [c796265ad38bbdc79dc17b2d0aba7e9e,cc0dbbd456ec...
# 3    3  ...
# 4    9  ...  [7f6347c263ce28650c650f3f050a4f70,b324dfcc8a36...
# 5    1  ...  [8375d3624fb8b896ff71ffc19d7f91cf,b324dfcc8a36...
# 6    2  ...  [acebe9382da99effdaf980d1072720f2,e201254a65d1...
# 7    7  ...  [671f5b5587e9f72661c822748941b868, 2baa5d7f2a9...
# 8    5  ...  [2feaa437afffb7674fa0506133b75626,671f5b5587e9...
# 9    0  ...  [1bf396570d5a75e44626a2dbcb8cf10b,2baa5d7f2a98...
# 10   4  ...  [8375d3624fb8b896ff71ffc19d7f91cf,9c1159fac63a...
# 11  21  ...  [cc0dbbd456ec94f96f25793657991734, 2baa5d7f2a9...
# 12  20  ...  [aa86232b2bed138127746cc93ab4c0bc,cc0dbbd456ec...
# 13  26  ...  [1cf5059e2eced944286c9661bca717e2,cc0dbbd456ec...
# 14  16  ...  [c796265ad38bbdc79dc17b2d0aba7e9e,cc0dbbd456ec...
# 15  24  ...  [aa86232b2bed138127746cc93ab4c0bc,cc0dbbd456ec...
# 16  17  ...  [671f5b5587e9f72661c822748941b868,c796265ad38b...
# 17  12  ...  [acebe9382da99effdaf980d1072720f2,e201254a65d1...
# 18  11  ...  [7f6347c263ce28650c650f3f050a4f70,9c1159fac63a...
# 19  18  ...  [671f5b5587e9f72661c822748941b868, 2baa5d7f2a9...
# 20  19  ...                 [671f5b5587e9f72661c822748941b868]
# 21  14  ...  [2feaa437afffb7674fa0506133b75626,671f5b5587e9...
# 22  27  ...                 [1cf5059e2eced944286c9661bca717e2]
# 23  25  ...                 [1cf5059e2eced944286c9661bca717e2]
# 24  13  ...  [2feaa437afffb7674fa0506133b75626,cd0c2f9e8eaf...
# 25  15  ...
# 26  23  ...
# 27  22  ...
# 28  29  ...  [671f5b5587e9f72661c822748941b868,c796265ad38b...
# 29  28  ...
#
# [30 rows x 6 columns]
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# 🚀 join_text_units_to_entity_ids
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
#                        text_unit_ids  ...                                id
# 0   cc0dbbd456ec94f96f25793657991734  ...  cc0dbbd456ec94f96f25793657991734
# 1   aa86232b2bed138127746cc93ab4c0bc  ...  aa86232b2bed138127746cc93ab4c0bc
# 2   2baa5d7f2a9844571079d991957cec9a  ...  2baa5d7f2a9844571079d991957cec9a
# 3   acebe9382da99effdaf980d1072720f2  ...  acebe9382da99effdaf980d1072720f2
# 4   f791c070bd270519bbffc7dd4eb08b3a  ...  f791c070bd270519bbffc7dd4eb08b3a
# 5   1cf5059e2eced944286c9661bca717e2  ...  1cf5059e2eced944286c9661bca717e2
# 6   c796265ad38bbdc79dc17b2d0aba7e9e  ...  c796265ad38bbdc79dc17b2d0aba7e9e
# 7   b324dfcc8a3699591c60646ccaf6e4b0  ...  b324dfcc8a3699591c60646ccaf6e4b0
# 8   7f6347c263ce28650c650f3f050a4f70  ...  7f6347c263ce28650c650f3f050a4f70
# 9   8375d3624fb8b896ff71ffc19d7f91cf  ...  8375d3624fb8b896ff71ffc19d7f91cf
# 10  671f5b5587e9f72661c822748941b868  ...  671f5b5587e9f72661c822748941b868
# 11  e201254a65d111262b3361be30dbaa31  ...  e201254a65d111262b3361be30dbaa31
# 12  9c1159fac63a5f8b3069d98ad9224551  ...  9c1159fac63a5f8b3069d98ad9224551
# 13  2feaa437afffb7674fa0506133b75626  ...  2feaa437afffb7674fa0506133b75626
# 14  cd0c2f9e8eaf3dddb95a58b3f5fdb8ef  ...  cd0c2f9e8eaf3dddb95a58b3f5fdb8ef
# 15  1bf396570d5a75e44626a2dbcb8cf10b  ...  1bf396570d5a75e44626a2dbcb8cf10b
#
# [16 rows x 3 columns]
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# └── create_final_relationships
# ⠇ GraphRAG Indexer 0
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# └── create_final_relationships
# ⠇ GraphRAG Indexer 0
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/datashaper/en
# gine/verbs/convert.py:65: FutureWarning: errors='ignore' is deprecated and will
# raise in a future version. Use to_numeric without passing `errors` and catch
# exceptions explicitly instead
#   column_numeric = cast(pd.Series, pd.to_numeric(column, errors="ignore"))
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# └── create_final_relationships
# ⠏ GraphRAG Indexer 0
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# 🚀 create_final_relationships
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
#                        source                target  ...  target_degree rank
# 0    UNITED STATES OF AMERICA      WASHINGTON, D.C.  ...             19   34
# 1    UNITED STATES OF AMERICA                CANADA  ...              1   16
# 2    UNITED STATES OF AMERICA                MEXICO  ...              1   16
# 3    UNITED STATES OF AMERICA                ALASKA  ...              1   16
# 4    UNITED STATES OF AMERICA                HAWAII  ...              1   16
# ..                        ...                   ...  ...            ...  ...
# 292                      LYON        FOURVIÈRE HILL  ...              1   17
# 293                      LYON            PRESQU'ÎLE  ...              1   17
# 294                      LYON          CROIX-ROUSSE  ...              1   17
# 295             U.S. CONGRESS      CAPITOL BUILDING  ...              1    3
# 296                ALEXANDRIA  DISTRICT OF COLUMBIA  ...              2    3
#
# [297 rows x 10 columns]
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# 🚀 join_text_units_to_relationship_ids
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
#                                   id
# relationship_ids
# 0   cc0dbbd456ec94f96f25793657991734  [42be4e140061482ea509dd3e26189480,
# 4da4ef951ff...
# 1   aa86232b2bed138127746cc93ab4c0bc  [d53f15cb7f7845de91cc44ad44ff9f6e,
# 23becf8c6fc...
# 2   2baa5d7f2a9844571079d991957cec9a  [f2c06f3a0c704296bf3353b91ee8af47,
# ff5466607e5...
# 3   f791c070bd270519bbffc7dd4eb08b3a  [f512103ed4624accac6cbbf90d7d250a,
# 5ecf534a9ff...
# 4   acebe9382da99effdaf980d1072720f2  [2325dafe50d1435cbee8ebcaa69688df,
# 67bb4f46782...
# 5   1cf5059e2eced944286c9661bca717e2  [2fb66f9a0de6406d83b61742a3b52cd6,
# b0e6cfd979e...
# 6   c796265ad38bbdc79dc17b2d0aba7e9e  [4d183e7007624fcd98af96b9d752c16d,
# 57b8930790c...
# 7   b324dfcc8a3699591c60646ccaf6e4b0  [bdddcb17ba6c408599dd395ce64f960a,
# bc70fee2061...
# 8   7f6347c263ce28650c650f3f050a4f70  [92646910ee624bd7909fac2b5c0232e3,
# ccbbbcc055c...
# 9   8375d3624fb8b896ff71ffc19d7f91cf  [05913bee89a94bca88449249e35ba74d,
# fe8ea8bf139...
# 10  671f5b5587e9f72661c822748941b868  [5c02b1ab32064c64a0f8b27b219e358a,
# 3073b33926b...
# 11  e201254a65d111262b3361be30dbaa31  [453ecf5476f64f4a8d5020b95baf1314,
# 6a1d83c9ce2...
# 12  9c1159fac63a5f8b3069d98ad9224551  [989add81cf874018a569239b68d17ff2,
# 53d98f08e7c...
# 13  2feaa437afffb7674fa0506133b75626  [71f95003936e46a98d90757ffd845d40,
# d0a274e7934...
# 14  cd0c2f9e8eaf3dddb95a58b3f5fdb8ef  [0a799eab61bc4e6b884db6689f9c2c4a,
# fdcb1673254...
# 15  1bf396570d5a75e44626a2dbcb8cf10b  [216ee8a907a0466a88b27f8ada19ffa0,
# 6fefb317687...
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ...
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# 🚀 create_final_text_units
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
#                                   id  ...
# relationship_ids
# 0   cc0dbbd456ec94f96f25793657991734  ...  [42be4e140061482ea509dd3e26189480,
# 4da4ef951ff...
# 1   b324dfcc8a3699591c60646ccaf6e4b0  ...  [bdddcb17ba6c408599dd395ce64f960a,
# bc70fee2061...
# 2   c796265ad38bbdc79dc17b2d0aba7e9e  ...  [4d183e7007624fcd98af96b9d752c16d,
# 57b8930790c...
# 3   e201254a65d111262b3361be30dbaa31  ...  [453ecf5476f64f4a8d5020b95baf1314,
# 6a1d83c9ce2...
# 4   7f6347c263ce28650c650f3f050a4f70  ...  [92646910ee624bd7909fac2b5c0232e3,
# ccbbbcc055c...
# 5   671f5b5587e9f72661c822748941b868  ...  [5c02b1ab32064c64a0f8b27b219e358a,
# 3073b33926b...
# 6   2baa5d7f2a9844571079d991957cec9a  ...  [f2c06f3a0c704296bf3353b91ee8af47,
# ff5466607e5...
# 7   1bf396570d5a75e44626a2dbcb8cf10b  ...  [216ee8a907a0466a88b27f8ada19ffa0,
# 6fefb317687...
# 8   1cf5059e2eced944286c9661bca717e2  ...  [2fb66f9a0de6406d83b61742a3b52cd6,
# b0e6cfd979e...
# 9   f791c070bd270519bbffc7dd4eb08b3a  ...  [f512103ed4624accac6cbbf90d7d250a,
# 5ecf534a9ff...
# 10  2feaa437afffb7674fa0506133b75626  ...  [71f95003936e46a98d90757ffd845d40,
# d0a274e7934...
# 11  8375d3624fb8b896ff71ffc19d7f91cf  ...  [05913bee89a94bca88449249e35ba74d,
# fe8ea8bf139...
# 12  cd0c2f9e8eaf3dddb95a58b3f5fdb8ef  ...  [0a799eab61bc4e6b884db6689f9c2c4a,
# fdcb1673254...
# 13  9c1159fac63a5f8b3069d98ad9224551  ...  [989add81cf874018a569239b68d17ff2,
# 53d98f08e7c...
# 14  acebe9382da99effdaf980d1072720f2  ...  [2325dafe50d1435cbee8ebcaa69688df,
# 67bb4f46782...
# 15  aa86232b2bed138127746cc93ab4c0bc  ...  [d53f15cb7f7845de91cc44ad44ff9f6e,
# 23becf8c6fc...
#
# [16 rows x 6 columns]
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/datashaper/en
# gine/verbs/convert.py:72: FutureWarning: errors='ignore' is deprecated and will
# raise in a future version. Use to_datetime without passing `errors` and catch
# exceptions explicitly instead
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# └── create_base_documents
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/datashaper/en
# gine/verbs/convert.py:72: UserWarning: Could not infer format, so each element
# will be parsed individually, falling back to `dateutil`. To ensure parsing is
# consistent and as-expected, please specify a format.
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# └── create_base_documents
# 🚀 create_base_documents
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
#                                   id  ...         title
# 0   45118b491c6d36b4a415322d2c444105  ...        EU.txt
# 1   57bf53f538aec812a46d791c2d841fef  ...        sf.txt
# 2   4c2ff161b5f148f60ada3fbd03391301  ...       las.txt
# 3   ae9e38d22d19e470bb73a77fbb6b60f8  ...   seattle.txt
# 4   9b6b9d1a58bc691dd54a34680e736e8d  ...      mars.txt
# 5   d6061301be2e033108f2e34a3ea8f22f  ...      lyon.txt
# 6   713939d032c2c02215b16dd704885c0b  ...      wash.txt
# 7   10dbe8991bb9a7ab1dda37e9ccbedd78  ...      nice.txt
# 8   0134252ef584e1c209f4b4937c1d7a4f  ...        US.txt
# 9   ef613ab86e387aabcf046b426ee32221  ...        dc.txt
# 10  63486c02b166324e26ba2c8d04b86f63  ...        un.txt
# 11  dd4cc25417ca1866236c0f308e7f8ee3  ...    france.txt
# 12  474b35b12bfb44f1235cd856dcae3b43  ...     paris.txt
# 13  5a03438903936014f36728865626c03b  ...  westeuro.txt
# 14  147a4bae12320a91e5843421457c4c0e  ...        ny.txt
#
# [15 rows x 4 columns]
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
# 🚀 create_final_documents
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
#                                   id  ...         title
# 0   45118b491c6d36b4a415322d2c444105  ...        EU.txt
# 1   57bf53f538aec812a46d791c2d841fef  ...        sf.txt
# 2   4c2ff161b5f148f60ada3fbd03391301  ...       las.txt
# 3   ae9e38d22d19e470bb73a77fbb6b60f8  ...   seattle.txt
# 4   9b6b9d1a58bc691dd54a34680e736e8d  ...      mars.txt
# 5   d6061301be2e033108f2e34a3ea8f22f  ...      lyon.txt
# 6   713939d032c2c02215b16dd704885c0b  ...      wash.txt
# 7   10dbe8991bb9a7ab1dda37e9ccbedd78  ...      nice.txt
# 8   0134252ef584e1c209f4b4937c1d7a4f  ...        US.txt
# 9   ef613ab86e387aabcf046b426ee32221  ...        dc.txt
# 10  63486c02b166324e26ba2c8d04b86f63  ...        un.txt
# 11  dd4cc25417ca1866236c0f308e7f8ee3  ...    france.txt
# 12  474b35b12bfb44f1235cd856dcae3b43  ...     paris.txt
# 13  5a03438903936014f36728865626c03b  ...  westeuro.txt
# 14  147a4bae12320a91e5843421457c4c0e  ...        ny.txt
#
# [15 rows x 4 columns]
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 15 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
# └── create_final_documents
# 🚀 All workflows completed successfully.

# %%
import os
import networkx as nx
import matplotlib.pyplot as plt

# Step 1: Find the folder with the latest modification time
output_path = '/home/ljc/data/graphrag/ragtest6/output'
folders = [os.path.join(output_path, d) for d in os.listdir(output_path) if os.path.isdir(os.path.join(output_path, d))]
latest_folder = max(folders, key=os.path.getmtime)

# Step 2: Find the artifacts/merged_graph.graphml file in that folder
graphml_file_path = os.path.join(latest_folder, 'artifacts', 'merged_graph.graphml')

# Check if file exists
if not os.path.isfile(graphml_file_path):
    print(f"GraphML file not found: {graphml_file_path}")
else:
    # Step 3: Read the GraphML file and visualize it
    graph = nx.read_graphml(graphml_file_path)
    
    # Draw the graph
    plt.figure(figsize=(35, 35))  # Increase figure size
    pos = nx.kamada_kawai_layout(graph)  # Use kamada_kawai layout
    
    # Draw nodes and edges
    nx.draw_networkx_nodes(graph, pos, node_size=700, node_color='skyblue')
    nx.draw_networkx_edges(graph, pos, edge_color='gray', alpha=0.5)
    
    # Draw labels with better positioning
    nx.draw_networkx_labels(graph, pos, font_size=8, font_weight='regular', verticalalignment='bottom')
    
    plt.title('Optimized GraphML Visualization')
    plt.axis('off')
    plt.show()

# %%
# !python -m graphrag.query --root ./ragtest6 --method local \
    "Please help me plan my trip to the capital of France"
# Out:
# INFO: Reading settings from ragtest6/settings.yaml
#
# INFO: Vector Store Args: {}
# creating llm client with {'api_key': 'REDACTED,len=56', 'type': "openai_chat", 'model': 'gpt-4o-2024-08-06', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': None, 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
# creating embedding llm client with {'api_key': 'REDACTED,len=56', 'type': "openai_embedding", 'model': 'text-embedding-3-small', 'max_tokens': 4000, 'temperature': 0, 'top_p': 1, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': None, 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': None, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
#
# SUCCESS: Local Search Response:
# # Planning Your Trip to Paris, the Capital of France
#
# Paris, often referred to as the "City of Light," is a vibrant metropolis known for its rich history, cultural landmarks, and significant role in global affairs. As the capital of France, it offers a diverse array of attractions and activities that cater to all interests. Here’s a guide to help you plan your trip to this iconic city.
#
# ## Cultural and Historical Attractions
#
# Paris is home to some of the world's most renowned cultural institutions. The **Louvre**, the most-visited art museum globally, houses an extensive collection of art and historical artifacts, including the famous Mona Lisa [Data: Entities (98); Relationships (140)]. Another must-visit is the **Musée d'Orsay**, which is celebrated for its impressive collection of French Impressionist art [Data: Entities (99); Relationships (141)]. For those interested in modern and contemporary art, the **Pompidou Centre** is a notable destination [Data: Entities (102); Relationships (144)].
#
# ## International Organizations and Economic Influence
#
# Paris is not only a cultural hub but also a center for international diplomacy and economic governance. It hosts several key international organizations, such as **UNESCO** and the **OECD**, which play pivotal roles in global policy-making [Data: Entities (49, 105); Relationships (85, 147, 150)]. The presence of the **European Banking Authority** and the **European Securities and Markets Authority** underscores Paris's importance in financial regulation within the European Union [Data: Entities (111, 112); Relationships (153, 154)].
#
# ## Transportation and Accessibility
#
# Getting around Paris is convenient thanks to its extensive transportation network. The city is served by two major international airports, **Charles de Gaulle** and **Orly**, which are key gateways for international travelers [Data: Entities (94, 95); Relationships (136, 137)]. The **Paris Métro** is one of the busiest subway systems in Europe, making it easy to navigate the city and reach various attractions [Data: Entities (96); Relationships (138)].
#
# ## Sporting and Recreational Activities
#
# Paris has a rich sporting legacy, having hosted numerous international events such as the **Summer Olympics**, **FIFA World Cup**, and the **Tour de France**, which finishes on the iconic Avenue des Champs-Élysées [Data: Entities (117, 118, 122); Relationships (159, 160, 164)]. If you’re a sports enthusiast, consider visiting the **Stade de France**, a large stadium that hosts various major sporting events [Data: Entities (115); Relationships (157)].
#
# ## Conclusion
#
# Paris offers a unique blend of history, culture, and modernity, making it a perfect destination for travelers seeking diverse experiences. Whether you're exploring its world-class museums, attending international events, or simply enjoying the local cuisine and fashion, Paris promises an unforgettable journey. Make sure to plan your itinerary to include these highlights and immerse yourself in the vibrant life of this global city.
