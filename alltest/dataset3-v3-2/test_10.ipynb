# %%
# !cd /home/ljc/data/graphrag/ && python -m graphrag.index --init --root /home/ljc/data/graphrag/alltest/dataset3
# Out:
# Initializing project at /home/ljc/data/graphrag/alltest/dataset3
# ⠋ GraphRAG Indexer

# %%
# !cd /home/ljc/data/graphrag/ && python -m graphrag.index --root /home/ljc/data/graphrag/alltest/dataset3-v3-2
# Out:
# Logging enabled at r
# /data/jiacheng/graphrag/alltest/dataset3-v3-2/output/20240923-211201/reports/ind
# exing-engine.log
# ⠹ GraphRAG Indexer
# ⠹ GraphRAG Indexer e.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# └── create_base_text_units
# ⠼ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   3% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# └── create_base_text_units
# 🚀 create_base_text_units━━   0% -:--:-- 0:00:00
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
#                                   id  ... n_tokens
# 0   4212f9fd0743bef90b03bb610d6fa25a  ...     1193
# 1   79b86365328956971ad4ea3a93a1b658  ...       93
# 2   05a3084b7238a6947eb09d148f0fe64e  ...     1200
# 3   f6015b9e8c6b9888550e5f83dcd5fab3  ...      436
# 4   61c69ff648ac6dbcee2475e5a0b5fa7a  ...      712
# 5   37c1f58a2a4b115622faa4ccbe28fc1b  ...      519
# 6   f07161d4b1e7ce1e5bc77a0d102e95a3  ...      647
# 7   bad26e430262b769498c8ca2b9afd08b  ...      711
# 8   25f66d346d1445fb2177ff52b05beb27  ...      465
# 9   1acac85b4bcab5c0ece0f4a4a7fdff52  ...     1200
# 10  939bc9e630afb759fd1478fce3d50396  ...      802
# 11  abf5929b96612ab65b7592324227f8e0  ...      979
# 12  e652e26c8570d8637c91ffd16c9aa137  ...      801
# 13  c10a1eeedb026066c260dfc97ec42a04  ...      958
# 14  32a306beab4136b13b608e5685aa1e7f  ...      322
# 15  968fa9502389c97118edf9643808afbd  ...     1041
# 16  0fbee784e22575ac51dc956e1cffa5a1  ...     1200
# 17  4f4b3aeeefe4a5f790d783cc360a26db  ...      369
# 18  9b0358104b55d5c5404f1e187c16c238  ...     1200
# 19  cc8a665700dd64ea2b6682844deba336  ...      478
# 20  3242665777929d369f24b3bcf0dc435a  ...     1200
# 21  40d23419ddfe110b133933e88530b22f  ...      142
# 22  fbcd4fd628727c03680489f8f31a303b  ...      372
# 23  228412bb342df987c4eadb98cefff9e2  ...     1200
# 24  21c90b0ad75d2e03b4f6e9730fbe7382  ...      481
# 25  5c612144b547e7a41ab74c21983c9bb8  ...     1200
# 26  b3269e92d3c5d2aa2b4f134d8f1fe0e0  ...      217
# 27  dcdf649d832a52abf257e984d0152865  ...      951
# 28  88a69206019d36cc531ec22743b7f61a  ...     1200
# 29  dca5ee79ae6e3696358cf2e53a2259df  ...      717
# 30  ad76a9849c02319e75ffb12752ba23a2  ...      173
# 31  3748dbd11954076800328b47f4f0cf96  ...     1103
# 32  f162be18dc783d3c12cfa602a93f717e  ...        3
# 33  42acfbbe0715156e90909521372ef354  ...      266
# 34  f3ec58e00002830045f1766fccd07353  ...      375
# 35  4337ed559ef551a72195a4f765260f32  ...      997
# 36  83912a7d183206ded383ff6792bd15f0  ...      304
# 37  5e0facec3e40f39c1e9b3d909d59ae44  ...      612
# 38  fe7e344fefd5cd88f0cd3616fae9e3d1  ...     1033
# 39  4c71026214c60b14aa786b724eaae972  ...      644
#
# [40 rows x 5 columns]
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠴ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠧ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠙ GraphRAG Indexer 0m━━━━━━━━━━━━  47% 0:00:03 0:00:02
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠸ GraphRAG Indexer ━━━━━━━━━━━  51% 0:00:03 0:00:02
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠦ GraphRAG Indexer ╸━━━━━━━━━  60% 0:00:02 0:00:02
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠧ GraphRAG Indexer ╸━━━━━━━━━  60% 0:00:02 0:00:03
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠏ GraphRAG Indexer m╸━━━━━━━━  64% 0:00:02 0:00:03
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠋ GraphRAG Indexer m╸━━━━━━━━  64% 0:00:02 0:00:03
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠹ GraphRAG Indexer 0m╺━━━━━━━  67% 0:00:02 0:00:03
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠹ GraphRAG Indexer 91m╸━━━━━━  72% 0:00:02 0:00:03
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠼ GraphRAG Indexer 91m╸━━━━━━  72% 0:00:02 0:00:03
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠴ GraphRAG Indexer 91m╸━━━━━━  74% 0:00:02 0:00:03
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠧ GraphRAG Indexer ╺━━━━━  76% 0:00:02 0:00:03
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠏ GraphRAG Indexer ╺━  93% 0:00:01 0:00:03
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠋ GraphRAG Indexer ╸━  94% 0:00:01 0:00:04
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠹ GraphRAG Indexer ╸━  94% 0:00:01 0:00:04
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠼ GraphRAG Indexer ╸━  94% 0:00:01 0:00:04
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠴ GraphRAG Indexer ╸━  96% 0:00:01 0:00:04
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠦ GraphRAG Indexer ╺  96% 0:00:01 0:00:04
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠧ GraphRAG Indexer ╺  96% 0:00:01 0:00:04
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠏ GraphRAG Indexer ╺  97% 0:00:01 0:00:04
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠙ GraphRAG Indexer ╺  97% 0:00:01 0:00:04
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠸ GraphRAG Indexer ╺  98% 0:00:01 0:00:05
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠼ GraphRAG Indexer ╸  98% 0:00:01 0:00:05
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠦ GraphRAG Indexer ╸  99% 0:00:01 0:00:05
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠧ GraphRAG Indexer ╸  99% 0:00:01 0:00:05
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠧ GraphRAG Indexer ╸ 100% 0:00:01 0:00:05
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# └── create_summarized_entities
# ⠏ GraphRAG Indexer ╸ 100% 0:00:01 0:00:05
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# 🚀 create_summarized_entities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
#                                         entity_graph
# 0  <graphml xmlns="http://graphml.graphdrawing.or...
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# └── create_base_entity_graph
# ⠋ GraphRAG Indexer ━━━━━━━━━━━  33% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# └── create_base_entity_graph
# ⠙ GraphRAG Indexer ━━━━━━━━━━━  33% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# └── create_base_entity_graph
# ⠴ GraphRAG Indexer ━━━━━━━━━━━  67% 0:00:01 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# 🚀 create_base_entity_graph
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
#    level  ...                                         embeddings
# 0      0  ...  {'1898 CONSOLIDATION': [-0.02104543149471283, ...
# 1      1  ...  {'1898 CONSOLIDATION': [-0.01806003786623478, ...
# 2      2  ...  {'1898 CONSOLIDATION': [-0.01961752586066723, ...
#
# [3 rows x 3 columns]
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠸ GraphRAG Indexer  -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠏ GraphRAG Indexer ━━━   5% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠙ GraphRAG Indexer ━━━   9% 0:00:03 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠹ GraphRAG Indexer ━━━  27% 0:00:01 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠼ GraphRAG Indexer ━━━  73% 0:00:01 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠴ GraphRAG Indexer ━━━  86% 0:00:01 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠏ GraphRAG Indexer 0m━  95% 0:00:01 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# 🚀 create_final_entities-- 0:00:00
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
#                                    id  ...
# description_embedding
# 0    b45241d70f0e43fca764df95b2b81f77  ...  [-0.0005772536969743669,
# 0.004305817186832428,...
# 1    4119fd06010c494caa07f439b333f4c5  ...  [-0.02111087739467621,
# -0.021176302805542946, ...
# 2    d3835bf3dda84ead99deadbeac5d0d7d  ...  [0.0028134894091635942,
# 0.004924878478050232, ...
# 3    077d2820ae1845bcbb1803379a3d1eae  ...  [0.06652490049600601,
# 0.012002617120742798, 0....
# 4    3671ea0dd4e84c1a9b02c5ab2c8f4bac  ...  [-0.013658960349857807,
# -0.0003211712755728513...
# ..                                ...  ...
# ...
# 165  e19287afe00a431f9a593a4827d1b448  ...  [0.0002679254102986306,
# -0.041117701679468155,...
# 166  f2c06f3a0c704296bf3353b91ee8af47  ...  [-0.004005592316389084,
# -0.03140935301780701, ...
# 167  f512103ed4624accac6cbbf90d7d250a  ...  [-0.01942550204694271,
# -0.025451824069023132, ...
# 168  2325dafe50d1435cbee8ebcaa69688df  ...  [-0.011209946125745773,
# -0.029429886490106583,...
# 169  469aeef98cd1421fa123277b93d7b83a  ...  [0.011425655335187912,
# 0.0030576877761632204, ...
#
# [341 rows x 8 columns]
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numba/np/ufun
# c/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version
# 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found
# TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠇ GraphRAG Indexer m-:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠙ GraphRAG Indexer m-:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠸ GraphRAG Indexer m-:--:-- 0:00:01
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠦ GraphRAG Indexer m-:--:-- 0:00:02
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠏ GraphRAG Indexer m-:--:-- 0:00:03
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠸ GraphRAG Indexer m-:--:-- 0:00:04
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠦ GraphRAG Indexer m-:--:-- 0:00:05
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠇ GraphRAG Indexer m-:--:-- 0:00:06
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠴ GraphRAG Indexer  33% -:--:-- 0:00:06
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠏ GraphRAG Indexer  67% 0:00:01 0:00:07
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠹ GraphRAG Indexer  67% 0:00:01 0:00:07
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠇ GraphRAG Indexer m-:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ...
# a24e9df02e1...
# 22  fbcd4fd628727c03680489f8f31a303b  ...  [81446ea789b24eaf9eab02dc07c3d984,
# b4c7de7a824...
# 23  228412bb342df987c4eadb98cefff9e2  ...  [4d183e7007624fcd98af96b9d752c16d,
# bc70fee2061...
# 24  21c90b0ad75d2e03b4f6e9730fbe7382  ...  [ec45e1c400654c4f875046926486ded7,
# 047cd93e9d7...
# 25  5c612144b547e7a41ab74c21983c9bb8  ...  [f78b01b0d93948c283644ec58f7be74a,
# 8dbe8f9867e...
# 26  b3269e92d3c5d2aa2b4f134d8f1fe0e0  ...  [f78b01b0d93948c283644ec58f7be74a,
# fae3fe31deb...
# 27  dcdf649d832a52abf257e984d0152865  ...  [aa946d4379694a74ba0da37e69d2810a,
# 1e6cabc18fa...
# 28  88a69206019d36cc531ec22743b7f61a  ...  [268446fc52a54fd2837f73aeb3e0b74f,
# f6ddfa8491f...
# 29  dca5ee79ae6e3696358cf2e53a2259df  ...  [aa946d4379694a74ba0da37e69d2810a,
# db1295504da...
# 30  ad76a9849c02319e75ffb12752ba23a2  ...  [69db426b97714835bf4937180774787a,
# 4d839a10353...
# 31  3748dbd11954076800328b47f4f0cf96  ...  [0fc15cc3b44c4142a770feb4c037a6f7,
# e7b103a52e3...
# 32  42acfbbe0715156e90909521372ef354  ...  [aa946d4379694a74ba0da37e69d2810a,
# 091e998370d...
# 33  f3ec58e00002830045f1766fccd07353  ...  [aca3eb8924ac494486fe0bfe892f7f2e,
# eb7c93eeb9d...
# 34  4337ed559ef551a72195a4f765260f32  ...  [93e1d19f9bfa4c6b8962d56d10ea9483,
# 8046335ba70...
# 35  83912a7d183206ded383ff6792bd15f0  ...  [9c7bc862339d4a5bb21ee5154d9b33bb,
# ae521508bdc...
# 36  5e0facec3e40f39c1e9b3d909d59ae44  ...  [711ba818354546cea69f1532b92a2f26,
# d562223c17d...
# 37  fe7e344fefd5cd88f0cd3616fae9e3d1  ...  [fac4a59c2278498d83f9f1b4231ad62e,
# ecdc1020b10...
# 38  4c71026214c60b14aa786b724eaae972  ...  [3c4062de44d64870a3cc5913d5769244,
# 24652fab20d...
# 39  f162be18dc783d3c12cfa602a93f717e  ...
# None
#
# [40 rows x 6 columns]
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/datashaper/en
# gine/verbs/convert.py:72: FutureWarning: errors='ignore' is deprecated and will
# raise in a future version. Use to_datetime without passing `errors` and catch
# exceptions explicitly instead
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# └── create_base_documents
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/datashaper/en
# gine/verbs/convert.py:72: UserWarning: Could not infer format, so each element
# will be parsed individually, falling back to `dateutil`. To ensure parsing is
# consistent and as-expected, please specify a format.
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# └── create_base_documents
# 🚀 create_base_documents
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
#                                   id  ...                        title
# 0   bf1b8a55f957b1fbb880a51bd98fc8d8  ...               beijingcbd.txt
# 1   abee64711424aaf7e15ff23cab922309  ...                  beijing.txt
# 2   726edcf40dfe269da5d4c65c5d33545c  ...              centralpark.txt
# 3   b980a72c59f2037b84c8f34b6d728dd2  ...                   jingan.txt
# 4   30c3078d07d6da65be19581dfc8f9535  ...                       nm.txt
# 5   9dfa6ec43b16f66fc64a6d955e70fb0e  ...                    tower.txt
# 6   d2768a86440914eff0c29efaf9cc28ad  ...                   bridge.txt
# 7   9fd8c5b049624459c7f6afa19bac1c8c  ...                    forbi.txt
# 8   84060f900089a09e6b9e864f9112ea7d  ...                 shanghai.txt
# 9   dd4d2fde72f50507e8003f3bd0fdb723  ...                    uscap.txt
# 10  f435f556f7d28794438cd73fc5f903cf  ...                      esb.txt
# 11  e0d4907c27241979fc015748ac4b213a  ...                   whiteh.txt
# 12  bce10e506cfe4d2edb02e765cd2ac689  ...                   statue.txt
# 13  634c0e04bb943b0d5289e0821389ab89  ...                    china.txt
# 14  83c01f3fb16d65b2c8cd536fb795fcfd  ...                greatwall.txt
# 15  2e662263aace3baef20a1fd8a1cf5d60  ...                    times.txt
# 16  8f1299030b13e762ab89b1feb373e9f9  ...    adv_texts_direct_v3-2.txt
# 17  27e6a34029058fadc37b0e489aab97cb  ...                       US.txt
# 18  843f655fe946ac6254fe0ab80714f3be  ...                       dc.txt
# 19  83e49ef399f817542c6110a75a79f20d  ...                  bridge2.txt
# 20  dc3914d44e72a9d3491f85ff59876d0e  ...                   njroad.txt
# 21  6fc8b79e22b0ded24a893a8e7900e9d0  ...                       un.txt
# 22  0dfdee24ef4be3c5a1612890e73dca3d  ...                      met.txt
# 23  5da91350b325c292b1bc17afdd332ffa  ...                tiananmen.txt
# 24  932d9a4b133bda42fbc49b7c5b34fee2  ...                 yugarden.txt
# 25  5c36c1dcbf8e7795e7c8e188a0cfde41  ...                  fronzoo.txt
# 26  3632049c6dfef1a849b5599fb36ec09e  ...          nationairmuseum.txt
# 27  9cd991cf17130509ed5bc16c61fd2a45  ...                       ny.txt
# 28  c3f8082384ca01001a4c5052890d0bb5  ...                    haven.txt
# 29  695d7b127fe0336dddb3d47171afd9a8  ...  adv_texts_indirect_v3-2.txt
#
# [30 rows x 4 columns]
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
# 🚀 create_final_documents
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
#                                   id  ...                        title
# 0   bf1b8a55f957b1fbb880a51bd98fc8d8  ...               beijingcbd.txt
# 1   abee64711424aaf7e15ff23cab922309  ...                  beijing.txt
# 2   726edcf40dfe269da5d4c65c5d33545c  ...              centralpark.txt
# 3   b980a72c59f2037b84c8f34b6d728dd2  ...                   jingan.txt
# 4   30c3078d07d6da65be19581dfc8f9535  ...                       nm.txt
# 5   9dfa6ec43b16f66fc64a6d955e70fb0e  ...                    tower.txt
# 6   d2768a86440914eff0c29efaf9cc28ad  ...                   bridge.txt
# 7   9fd8c5b049624459c7f6afa19bac1c8c  ...                    forbi.txt
# 8   84060f900089a09e6b9e864f9112ea7d  ...                 shanghai.txt
# 9   dd4d2fde72f50507e8003f3bd0fdb723  ...                    uscap.txt
# 10  f435f556f7d28794438cd73fc5f903cf  ...                      esb.txt
# 11  e0d4907c27241979fc015748ac4b213a  ...                   whiteh.txt
# 12  bce10e506cfe4d2edb02e765cd2ac689  ...                   statue.txt
# 13  634c0e04bb943b0d5289e0821389ab89  ...                    china.txt
# 14  83c01f3fb16d65b2c8cd536fb795fcfd  ...                greatwall.txt
# 15  2e662263aace3baef20a1fd8a1cf5d60  ...                    times.txt
# 16  8f1299030b13e762ab89b1feb373e9f9  ...    adv_texts_direct_v3-2.txt
# 17  27e6a34029058fadc37b0e489aab97cb  ...                       US.txt
# 18  843f655fe946ac6254fe0ab80714f3be  ...                       dc.txt
# 19  83e49ef399f817542c6110a75a79f20d  ...                  bridge2.txt
# 20  dc3914d44e72a9d3491f85ff59876d0e  ...                   njroad.txt
# 21  6fc8b79e22b0ded24a893a8e7900e9d0  ...                       un.txt
# 22  0dfdee24ef4be3c5a1612890e73dca3d  ...                      met.txt
# 23  5da91350b325c292b1bc17afdd332ffa  ...                tiananmen.txt
# 24  932d9a4b133bda42fbc49b7c5b34fee2  ...                 yugarden.txt
# 25  5c36c1dcbf8e7795e7c8e188a0cfde41  ...                  fronzoo.txt
# 26  3632049c6dfef1a849b5599fb36ec09e  ...          nationairmuseum.txt
# 27  9cd991cf17130509ed5bc16c61fd2a45  ...                       ny.txt
# 28  c3f8082384ca01001a4c5052890d0bb5  ...                    haven.txt
# 29  695d7b127fe0336dddb3d47171afd9a8  ...  adv_texts_indirect_v3-2.txt
#
# [30 rows x 4 columns]
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
# └── create_final_documents
# 🚀 All workflows completed successfully.

# %%
import os
import networkx as nx
import matplotlib.pyplot as plt

# Step 1: Find the folder with the latest modification time
output_path = '/home/ljc/data/graphrag/alltest/dataset3/output'
folders = [os.path.join(output_path, d) for d in os.listdir(output_path) if os.path.isdir(os.path.join(output_path, d))]
latest_folder = max(folders, key=os.path.getmtime)

# Step 2: Find the artifacts/merged_graph.graphml file in that folder
graphml_file_path = os.path.join(latest_folder, 'artifacts', 'merged_graph.graphml')

# Check if file exists
if not os.path.isfile(graphml_file_path):
    print(f"GraphML file not found: {graphml_file_path}")
else:
    # Step 3: Read the GraphML file and visualize it
    graph = nx.read_graphml(graphml_file_path)
    
    # Draw the graph
    plt.figure(figsize=(35, 35))  # Increase figure size
    pos = nx.kamada_kawai_layout(graph)  # Use kamada_kawai layout
    
    # Draw nodes and edges
    nx.draw_networkx_nodes(graph, pos, node_size=700, node_color='skyblue')
    nx.draw_networkx_edges(graph, pos, edge_color='gray', alpha=0.5)
    
    # Draw labels with better positioning
    nx.draw_networkx_labels(graph, pos, font_size=8, font_weight='regular', verticalalignment='bottom')
    
    plt.title('Optimized GraphML Visualization')
    plt.axis('off')
    plt.show()

# %%
import networkx as nx

# Read the graph from the GraphML file
graph = nx.read_graphml(graphml_file_path)

# Extract nodes and edges
nodes = list(graph.nodes)
edges = list(graph.edges)

# Convert nodes to a string
nodes_str = ', '.join(nodes)

# Convert edges to a string
edges_str = '\n  - '.join([f"({u}, {v})" for u, v in edges])

# Print the graph description
print(f"Graph Description:\n- Nodes: {nodes_str}\n- Edges:\n  - {edges_str}")
# Out:
# Graph Description:
# - Nodes: METROPOLITAN MUSEUM OF ART, NEW YORK CITY, THE CLOISTERS, EMPIRE STATE BUILDING, HAMILTON E. JAMES, MAX HOLLEIN, CANDACE BEINECKE, SEVEN WONDERS OF THE MODERN WORLD, AMERICAN SOCIETY OF CIVIL ENGINEERS, AMERICAN INSTITUTE OF ARCHITECTS, NEW YORK CITY LANDMARKS PRESERVATION COMMISSION, NATIONAL REGISTER OF HISTORIC PLACES, NATIONAL HISTORIC LANDMARK, UNITED STATES OF AMERICA, WASHINGTON, D.C., JOE BIDEN, KAMALA HARRIS, MIKE JOHNSON, JOHN ROBERTS, CONGRESS, SENATE, HOUSE OF REPRESENTATIVES, AMERICAN REVOLUTION, AMERICAN CIVIL WAR, HAWAII, CANADA, MEXICO, GREAT BRITAIN, THIRTEEN COLONIES, CONFEDERATE STATES OF AMERICA, ALASKA, UNITED STATES, REVOLUTIONARY WAR, WORLD WAR II, COLD WAR, SOVIET UNION, UNION, PEARL HARBOR, WORLD BANK, ORGANIZATION OF AMERICAN STATES, NATO, UNITED NATIONS, TIMES SQUARE, THE NEW YORK TIMES, ONE TIMES SQUARE, NEW YEAR'S EVE BALL DROP, SEVENTH AVENUE, DUFFY SQUARE, LINCOLN HIGHWAY, BROADWAY, NATIONAL MALL, PIERRE CHARLES L'ENFANT, NATIONAL PARK SERVICE, UNITED STATES CAPITOL, WASHINGTON MONUMENT, LINCOLN MEMORIAL, JEFFERSON MEMORIAL, WEST POTOMAC PARK, CONSTITUTION GARDENS, SMITHSONIAN INSTITUTION, NATIONAL AIR AND SPACE MUSEUM, CHRIS BROWNE, PETER JAKAB, STEVEN F. UDVAR-HAZY CENTER, DULLES INTERNATIONAL AIRPORT, PAUL E. GARBER PRESERVATION, RESTORATION, AND STORAGE FACILITY, SUITLAND, MARYLAND, FRIENDSHIP 7, SPIRIT OF ST. LOUIS, WRIGHT FLYER, APOLLO 11 COMMAND MODULE COLUMBIA, BRONX ZOO, WILDLIFE CONSERVATION SOCIETY, BRONX PARK, NEW YORK, WILLIAM TEMPLE HORNADAY, AMERICAN BISON SOCIETY, PAUL MANSHIP, JUNGLEWORLD, WILD ASIA MONORAIL, MADAGASCAR!, TIGER MOUNTAIN, AFRICAN PLAINS, WORLD OF BIRDS, WORLD OF REPTILES, ZOO CENTER, CONGO GORILLA FOREST, TIANANMEN, BEIJING, MAO ZEDONG, PEOPLE'S REPUBLIC OF CHIN
#   - (UNITED STATES, ORGANIZATION OF AMERICAN STATES)
#   - (UNITED STATES, NATO)
#   - (UNITED STATES, UNITED NATIONS)
#   - (UNITED STATES, CHINA)
#   - (UNITED STATES, STATUE OF LIBERTY)
#   - (COLD WAR, SHANGHAI)
#   - (UNITED NATIONS, CHINA)
#   - (UNITED NATIONS, TURTLE BAY)
#   - (UNITED NATIONS, WALLACE HARRISON)
#   - (UNITED NATIONS, HARRISON & ABRAMOVITZ)
#   - (UNITED NATIONS, OSCAR NIEMEYER)
#   - (UNITED NATIONS, LE CORBUSIER)
#   - (UNITED NATIONS, GENEVA)
#   - (UNITED NATIONS, VIENNA)
#   - (UNITED NATIONS, NAIROBI)
#   - (UNITED NATIONS, UNICEF)
#   - (UNITED NATIONS, SECRETARIAT)
#   - (UNITED NATIONS, CONFERENCE BUILDING)
#   - (UNITED NATIONS, GENERAL ASSEMBLY)
#   - (UNITED NATIONS, DAG HAMMARSKJÖLD LIBRARY)
#   - (UNITED NATIONS, SECURITY COUNCIL)
#   - (TIMES SQUARE, THE NEW YORK TIMES)
#   - (TIMES SQUARE, ONE TIMES SQUARE)
#   - (TIMES SQUARE, NEW YEAR'S EVE BALL DROP)
#   - (TIMES SQUARE, BROADWAY)
#   - (TIMES SQUARE, SEVENTH AVENUE)
#   - (TIMES SQUARE, DUFFY SQUARE)
#   - (TIMES SQUARE, LINCOLN HIGHWAY)
#   - (NATIONAL MALL, PIERRE CHARLES L'ENFANT)
#   - (NATIONAL MALL, NATIONAL PARK SERVICE)
#   - (NATIONAL MALL, UNITED STATES CAPITOL)
#   - (NATIONAL MALL, WASHINGTON MONUMENT)
#   - (NATIONAL MALL, LINCOLN MEMORIAL)
#   - (NATIONAL MALL, JEFFERSON MEMORIAL)
#   - (NATIONAL MALL, SMITHSONIAN INSTITUTION)
#   - (NATIONAL MALL, WEST POTOMAC PARK)
#   - (NATIONAL MALL, CONSTITUTION GARDENS)
#   - (NATIONAL MALL, U.S. CAPITOL)
#   - (NATIONAL MALL, SMITHSONIAN NATIONAL AIR AND SPACE MUSEUM)
#   - (NATIONAL PARK SERVICE, STATUE OF LIBERTY)
#   - (UNITED STATES CAPITOL, WILLIAM THORNTON)
#   - (UNITED STATES CAPITOL, BENJAMIN HENRY LATROBE)
#   - (UNITED STATES CAPITOL, CAPITOL HILL)
#   - (UNITED STATES CAPITOL, BURNING OF WASHINGTON)
#   - (UNITED STATES CAPITOL, UNITED STATES CONGRESS)
#   - (UNITED STATES CAPITOL, ARCHITECT OF THE CAPITOL)
#   - (NATIONAL AIR AND SPACE MUSEUM, CHRIS BROWNE)
#   - (NATIONAL AIR AND SPACE MUSEUM, PETER JAKAB)
#   - (NATIONAL AIR AND SPACE MUSEUM, STEVEN F. UDVAR-HAZY CENTER)
#   - (NATIONAL AIR AND SPACE MUSEUM, PAUL E. GARBER PRESERVATION, RESTORATION, AND STORAGE FACILITY)
#   - (NATIONAL AIR AND SPACE MUSEUM, APOLLO 11 COMMAND MODULE COLUMBIA)
#   - (NATIONAL AIR AND SPACE MUSEUM, FRIENDSHIP 7)
#   - (NATIONAL AIR AND SPACE MUSEUM, SPIRIT OF ST. LOUIS)
#   - (NATIONAL AIR AND SPACE MUSEUM, WRIGHT FLYER)
#   - (STEVEN F. UDVAR-HAZY CENTER, DULLES INTERNATIONAL AIRPORT)
#   - (PAUL E. GARBER PRESERVATION, RESTORATION, AND STORAGE FACILITY, SUITLAND, MARYLAND)
#   - (BRONX ZOO, WILDLIFE CONSERVATION SOCIETY)
#   - (BRONX ZOO, BRONX PARK)
#   - (BRONX ZOO, WILLIAM TEMPLE HORNADAY)
#   - (BRONX ZOO, AMERICAN BISON SOCIETY)
#   - (BRONX ZOO, PAUL MANSHIP)
#   - (BRONX ZOO, NEW YORK)
#   - (BRONX ZOO, CONGO GORILLA FOREST)
#   - (BRONX ZOO, JUNGLEWORLD)
#   - (BRONX ZOO, WILD ASIA MONORAIL)
#   - (BRONX ZOO, MADAGASCAR!)
#   - (BRONX ZOO, TIGER MOUNTAIN)
#   - (BRONX ZOO, AFRICAN PLAINS)
#   - (BRONX ZOO, WORLD OF BIRDS)
#   - (BRONX ZOO, WORLD OF REPTILES)
#   - (BRONX ZOO, ZOO CENTER)
#   - (TIANANMEN, BEIJING)
#   - (TIANANMEN, MAO ZEDONG)
#   - (TIANANMEN, PEOPLE'S REPUBLIC OF CHINA)
#   - (TIANANMEN, TIANANMEN SQUARE)
#   - (TIANANMEN, FORBIDDEN CITY)
#   - (TIANANMEN, CHANG'AN AVENUE)
#   - (BEIJING, TIANANMEN SQUARE)
#   - (BEIJING, FORBIDDEN CITY)
#   - (BEIJING, CHANG'AN AVENUE)
#   - (BEIJING, PEOPLE'S REPUBLIC OF CHINA)
#   - (BEIJING, BADALING)
#   - (BEIJING, JUYONGGUAN PASS)
#   - (BEIJING, CHINA)
#   - (BEIJING, HEBEI PROVINCE)
#   - (BEIJING, TIANJIN)
#   - (BEIJING, JING-JIN-JI)
#   - (BEIJING, BEIJING CAPITAL INTERNATIONAL AIRPORT)
#   - (BEIJING, BEIJING DAXING INTERNATIONAL AIRPORT)
#   - (BEIJING, YIN YONG)
#   - (BEIJING, WEI XIAODONG)
#   - (BEIJING, 2008 SUMMER OLYMPICS)
#   - (BEIJING, 2022 WINTER OLYMPICS)
#   - (BEIJING, TEMPLE OF HEAVEN)
#   - (BEIJING, SUMMER PALACE)
#   - (BEIJING, MING TOMBS)
#   - (BEIJING, ZHOUKOUDIAN PEKING MAN SITE)
#   - (BEIJING, BEIJING CENTRAL AXIS)
#   - (BEIJING, GREAT WALL)
#   - (BEIJING, GRAND CANAL)
#   - (BEIJING, TSINGHUA UNIVERSITY)
#   - (BEIJING, PEKING UNIVERSITY)
#   - (BEIJING, ASIAN INFRASTRUCTURE INVESTMENT BANK)
#   - (BEIJING, SHANGHAI COOPERATION ORGANISATION)
#   - (BEIJING, SILK ROAD FUND)
#   - (BEIJING, CHINESE ACADEMY OF SCIENCES)
#   - (BEIJING, CHINESE ACADEMY OF ENGINEERING)
#   - (BEIJING, CHINESE ACADEMY OF SOCIAL SCIENCES)
#   - (BEIJING, CENTRAL ACADEMY OF FINE ARTS)
#   - (BEIJING, CENTRAL ACADEMY OF DRAMA)
#   - (BEIJING, CENTRAL CONSERVATORY OF MUSIC)
#   - (BEIJING, RED CROSS SOCIETY OF CHINA)
#   - (BEIJING, BEIJING SUBWAY)
#   - (BEIJING, BEIJING CBD)
#   - (BEIJING, ZHONGGUANCUN)
#   - (MAO ZEDONG, PEOPLE'S REPUBLIC OF CHINA)
#   - (MAO ZEDONG, CHINESE COMMUNIST PARTY)
#   - (PEOPLE'S REPUBLIC OF CHINA, SHANGHAI)
#   - (PEOPLE'S REPUBLIC OF CHINA, XI JINPING)
#   - (PEOPLE'S REPUBLIC OF CHINA, LI QIANG)
#   - (PEOPLE'S REPUBLIC OF CHINA, WANG HUNING)
#   - (PEOPLE'S REPUBLIC OF CHINA, HAN ZHENG)
#   - (PEOPLE'S REPUBLIC OF CHINA, CHONGQING)
#   - (PEOPLE'S REPUBLIC OF CHINA, TAIWAN)
#   - (PEOPLE'S REPUBLIC OF CHINA, QIN DYNASTY)
#   - (PEOPLE'S REPUBLIC OF CHINA, HAN DYNASTY)
#   - (PEOPLE'S REPUBLIC OF CHINA, TANG DYNASTY)
#   - (PEOPLE'S REPUBLIC OF CHINA, YUAN DYNASTY)
#   - (PEOPLE'S REPUBLIC OF CHINA, MING DYNASTY)
#   - (PEOPLE'S REPUBLIC OF CHINA, QING DYNASTY)
#   - (FORBIDDEN CITY, PALACE MUSEUM)
#   - (FORBIDDEN CITY, MING DYNASTY)
#   - (FORBIDDEN CITY, QING DYNASTY)
#   - (FORBIDDEN CITY, CHINA)
#   - (FORBIDDEN CITY, YONGLE EMPEROR)
#   - (SHANGHAI, CHINA)
#   - (SHANGHAI, YANGTZE RIVER)
#   - (SHANGHAI, HUANGPU RIVER)
#   - (SHANGHAI, PORT OF SHANGHAI)
#   - (SHANGHAI, PUDONG NEW AREA)
#   - (SHANGHAI, BATTLE OF SHANGHAI)
#   - (SHANGHAI, FIRST OPIUM WAR)
#   - (SHANGHAI, CHINESE CIVIL WAR)
#   - (SHANGHAI, DENG XIAOPING)
#   - (SHANGHAI, SHANGHAI MUNICIPAL PEOPLE'S CONGRESS)
#   - (SHANGHAI, SHESHAN HILL)
#   - (SHANGHAI, THE BUND)
#   - (SHANGHAI, LUJIAZUI)
#   - (SHANGHAI, YU GARDEN)
#   - (SHANGHAI, NANJING ROAD)
#   - (SHANGHAI, SHANGHAI EXHIBITION CENTRE)
#   - (SHANGHAI, OLD CITY OF SHANGHAI)
#   - (SHANGHAI, JING'AN TEMPLE)
#   - (SHANGHAI, SHANGHAI STOCK EXCHANGE)
#   - (SHANGHAI, SHANGHAI FREE-TRADE ZONE)
#   - (SHANGHAI, CITY GOD TEMPLE)
#   - (SHANGHAI, CHINA PAVILION)
#   - (SHANGHAI, BUND)
#   - (SHANGHAI, ORIENTAL PEARL TOWER)
#   - (SHANGHAI, EASTERN BLOC)
#   - (SHANGHAI, GLOBALIZATION AND WORLD CITIES RESEARCH NETWORK)
#   - (SHANGHAI, GLOBAL FINANCIAL CENTRES INDEX)
#   - (SHANGHAI, FORTUNE GLOBAL 500)
#   - (SHANGHAI, SHANGHAI METRO)
#   - (SHANGHAI, SHANGHAI TOWER)
#   - (ZHAO LEJI, NATIONAL PEOPLE'S CONGRESS)
#   - (MING DYNASTY, BADALING)
#   - (MING DYNASTY, GREAT WALL OF CHINA)
#   - (MING DYNASTY, TEMPLE OF HEAVEN)
#   - (QING DYNASTY, TEMPLE OF HEAVEN)
#   - (QIN, HAN)
#   - (HAN, TANG)
#   - (TANG, YUAN)
#   - (YUAN, MING)
#   - (MING, QING)
#   - (SILK ROAD, CHINA)
#   - (GREAT WALL, CHINA)
#   - (CHINA, TIANANMEN SQUARE PROTESTS)
#   - (CHINA, AIIB)
#   - (CHINA, SILK ROAD FUND)
#   - (CHINA, NEW DEVELOPMENT BANK)
#   - (CHINA, RCEP)
#   - (CHINA, BRICS)
#   - (CHINA, G20)
#   - (CHINA, APEC)
#   - (CHINA, SCO)
#   - (CHINA, EAST ASIA SUMMIT)
#   - (CHINA, UN SECURITY COUNCIL)
#   - (CHINA, BRITAIN)
#   - (CHINA, FRANCE)
#   - (CHINA, GERMANY)
#   - (CHINA, RUSSIA)
#   - (CHINA, PORTUGAL)
#   - (CHINA, JING'AN TEMPLE)
#   - (CHINA, TEMPLE OF HEAVEN)
#   - (REPUBLIC OF CHINA, BEIYANG GOVERNMENT)
#   - (KUOMINTANG, CHINESE COMMUNIST PARTY)
#   - (EMPIRE OF JAPAN, SECOND SINO-JAPANESE WAR)
#   - (SECOND SINO-JAPANESE WAR, BATTLE OF SHANGHAI)
#   - (GREAT LEAP FORWARD, GREAT CHINESE FAMINE)
#   - (CULTURAL REVOLUTION, MAOIST POPULISM)
#   - (SINO-SOVIET SPLIT, SHANGHAI COMMUNIQUÉ)
#   - (FRANCE, STATUE OF LIBERTY)
#   - (CENTRAL PARK, FREDERICK LAW OLMSTED)
#   - (CENTRAL PARK, CALVERT VAUX)
#   - (CENTRAL PARK, NYC PARKS)
#   - (CENTRAL PARK, CENTRAL PARK CONSERVANCY)
#   - (CENTRAL PARK, SENECA VILLAGE)
#   - (CENTRAL PARK, MANHATTAN)
#   - (CENTRAL PARK, UPPER WEST SIDE)
#   - (CENTRAL PARK, UPPER EAST SIDE)
#   - (CENTRAL PARK, ROBERT MOSES)
#   - (CENTRAL PARK, SHAKESPEARE IN THE PARK)
#   - (ROBERT MOSES, VERRAZZANO-NARROWS BRIDGE)
#   - (MANHATTAN, WALL STREET)
#   - (MANHATTAN, FINANCIAL DISTRICT)
#   - (MANHATTAN, BROOKLYN BRIDGE)
#   - (BADALING, GREAT WALL OF CHINA)
#   - (BADALING, BADALING TOWN)
#   - (BADALING, YANQING DISTRICT)
#   - (BADALING, BEIBALOU)
#   - (BADALING, JUYONGGUAN PASS)
#   - (YANQING DISTRICT, BADALING TOWN)
#   - (VERRAZZANO-NARROWS BRIDGE, STATEN ISLAND)
#   - (VERRAZZANO-NARROWS BRIDGE, BROOKLYN)
#   - (VERRAZZANO-NARROWS BRIDGE, THE NARROWS)
#   - (VERRAZZANO-NARROWS BRIDGE, OTHMAR AMMANN)
#   - (VERRAZZANO-NARROWS BRIDGE, LEOPOLD JUST)
#   - (VERRAZZANO-NARROWS BRIDGE, AMMANN & WHITNEY)
#   - (VERRAZZANO-NARROWS BRIDGE, GIOVANNI DA VERRAZZANO)
#   - (VERRAZZANO-NARROWS BRIDGE, INTERSTATE 278)
#   - (VERRAZZANO-NARROWS BRIDGE, MTA BRIDGES AND TUNNELS)
#   - (BROOKLYN, BROOKLYN BRIDGE)
#   - (THE NARROWS, LOWER NEW YORK BAY)
#   - (THE NARROWS, NEW YORK HARBOR)
#   - (LOWER NEW YORK BAY, ATLANTIC OCEAN)
#   - (NEW YORK HARBOR, STATUE OF LIBERTY)
#   - (HUANGPU RIVER, EXQUISITE JADE ROCK)
#   - (HUANGPU RIVER, ORIENTAL PEARL TOWER)
#   - (HSBC BUILDING, THE BUND)
#   - (LUJIAZUI, ORIENTAL PEARL TOWER)
#   - (LUJIAZUI, SHANGHAI TOWER)
#   - (LUJIAZUI, PUDONG)
#   - (SHANGHAI TOWER, SHANGHAI MUNICIPAL GOVERNMENT)
#   - (SHANGHAI TOWER, BURJ KHALIFA)
#   - (SHANGHAI TOWER, J HOTEL)
#   - (SHANGHAI TOWER, OBSERVATION DECK)
#   - (SHANGHAI TOWER, TOP OF SHANGHAI)
#   - (YU GARDEN, HUANGPU DISTRICT)
#   - (YU GARDEN, CITY GOD TEMPLE)
#   - (YU GARDEN, YUYUAN TOURIST MART)
#   - (YU GARDEN, HUXINTING TEAHOUSE)
#   - (YU GARDEN, YU GARDEN BAZAAR)
#   - (YU GARDEN, EXQUISITE JADE ROCK)
#   - (YU GARDEN, SHANGHAI METRO)
#   - (NANJING ROAD, JIANGSU)
#   - (NANJING ROAD, NANJING)
#   - (NANJING ROAD, SHANGHAI INTERNATIONAL SETTLEMENT)
#   - (NANJING ROAD, BUBBLING WELL ROAD)
#   - (NANJING ROAD, SHANGHAI RACE CLUB)
#   - (NANJING ROAD, EAST NANJING ROAD)
#   - (NANJING ROAD, WEST NANJING ROAD)
#   - (JING'AN TEMPLE, BUDDHISM)
#   - (WHITE HOUSE, JAMES HOBAN)
#   - (WHITE HOUSE, BENJAMIN HENRY LATROBE)
#   - (WHITE HOUSE, JOHN ADAMS)
#   - (WHITE HOUSE, THOMAS JEFFERSON)
#   - (WHITE HOUSE, JAMES MONROE)
#   - (WHITE HOUSE, THEODORE ROOSEVELT)
#   - (WHITE HOUSE, WILLIAM HOWARD TAFT)
#   - (WHITE HOUSE, HARRY S. TRUMAN)
#   - (WHITE HOUSE, EISENHOWER EXECUTIVE OFFICE BUILDING)
#   - (WHITE HOUSE, BLAIR HOUSE)
#   - (WHITE HOUSE, EXECUTIVE RESIDENCE)
#   - (WHITE HOUSE, WEST WING)
#   - (WHITE HOUSE, EAST WING)
#   - (WHITE HOUSE, PRESIDENT'S PARK)
#   - (EXQUISITE JADE ROCK, HUOZONG EMPEROR)
#   - (HUOZONG EMPEROR, NORTHERN SONG DYNASTY)
#   - (STATUE OF LIBERTY, LIBERTY ISLAND)
#   - (STATUE OF LIBERTY, FRÉDÉRIC AUGUSTE BARTHOLDI)
#   - (STATUE OF LIBERTY, GUSTAVE EIFFEL)
#   - (STATUE OF LIBERTY, ÉDOUARD DE LABOULAYE)
#   - (STATUE OF LIBERTY, JOSEPH PULITZER)
#   - (STATUE OF LIBERTY, GROVER CLEVELAND)
#   - (STATUE OF LIBERTY, CENTENNIAL EXPOSITION)
#   - (STATUE OF LIBERTY, MADISON SQUARE PARK)
#   - (BROOKLYN BRIDGE, JOHN AUGUSTUS ROEBLING)
#   - (BROOKLYN BRIDGE, WASHINGTON ROEBLING)
#   - (BROOKLYN BRIDGE, EMILY WARREN ROEBLING)
#   - (BROOKLYN BRIDGE, EAST RIVER)
#   - (BROOKLYN BRIDGE, NEW YORK BRIDGE COMPANY)
#   - (BROOKLYN BRIDGE, DUMBO)
#   - (BROOKLYN BRIDGE, BROOKLYN HEIGHTS)
#   - (BROOKLYN BRIDGE, CIVIC CENTER)
#   - (BROOKLYN BRIDGE, MAY 24, 1883)
#   - (DUKE OF YORK, KING CHARLES II)
#   - (BURJ KHALIFA, DUBAI)
#   - (PALACE MUSEUM, WANG XUDONG)
#   - (LI XIULING, BEIJING MUNICIPAL PEOPLE'S CONGRESS)
#   - (BEIJING MUNICIPAL PEOPLE'S CONGRESS, YIN LI)
#   - (TEMPLE OF HEAVEN, UNESCO WORLD HERITAGE SITE)
#   - (BEIJING CBD, CHAOYANG DISTRICT)
#   - (BEIJING CBD, CITIC TOWER)
#   - (CENTENNIAL EXPOSITION, PHILADELPHIA)
#   - (NEW YORK BRIDGE COMPANY, TAMMANY HALL)
#   - (BUBBLING WELL ROAD, WEST NANJING ROAD)
#   - (WEST WING, OVAL OFFICE)

# %%
# !cd /home/ljc/data/graphrag/ && python -m graphrag.query --root /home/ljc/data/graphrag/alltest/basedataset/test1 --method local \
    "Is PARIS associated with more than one UNESCO-related entity?"
# Out:
# INFO: Vector Store Args: {}
# creating llm client with {'api_key': 'REDACTED,len=132', 'type': "openai_chat", 'model': 'gpt-4o-2024-08-06', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': None, 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
# creating embedding llm client with {'api_key': 'REDACTED,len=132', 'type': "openai_embedding", 'model': 'text-embedding-3-small', 'max_tokens': 4000, 'temperature': 0, 'top_p': 1, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': None, 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': None, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
#
# SUCCESS: Local Search Response:
# Yes, Paris is associated with more than one UNESCO-related entity.
#
# ### UNESCO Headquarters
#
# Paris is home to the headquarters of UNESCO, the United Nations Educational, Scientific and Cultural Organization. UNESCO is a specialized agency of the United Nations that focuses on promoting world peace and security through international cooperation in education, the sciences, and culture [Data: Entities (52); Relationships (94)].
#
# ### UNESCO World Heritage Site
#
# Additionally, the historical district along the Seine in the city center of Paris has been classified as a UNESCO World Heritage Site since 1991. This designation highlights the cultural and historical significance of the area, further associating Paris with UNESCO's mission of preserving world heritage [Data: Sources (4)].
#
# These associations underscore Paris's role as a significant center for cultural and historical preservation on a global scale.
