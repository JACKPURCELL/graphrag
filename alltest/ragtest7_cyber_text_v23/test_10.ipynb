# %%
# !original_dir=$(pwd) && cd /home/ljc/data/graphrag/ && python -m graphrag.index --root "$original_dir"
# Out:
# Logging enabled at r
# /data/jiacheng/graphrag/alltest/ragtest7_cyber_text_v23/output/20240928-163317/r
# eports/indexing-engine.log
# ⠼ GraphRAG Indexer
# ⠼ GraphRAG Indexer e.text) - 280 files loaded (0 filtered)  100%  0…
# ├── Loading Input (InputFileType.text) - 280 files loaded (0 filtered)  100%  0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 280 files loaded (0 filtered)  100%  0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 280 files loaded (0 filtered)  100%  0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 280 files loaded (0 filtered)  100%  0…
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 280 files loaded (0 filtered)  100%  0…
# └── create_base_text_units
# ⠧ GraphRAG Indexer ━━━━━━━━━━━━━━━━━   0% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 280 files loaded (0 filtered)  100%  0…
# └── create_base_text_units
# ⠧ GraphRAG Indexer ━━━━━━━━━━━━━━━╺━  95% 0:00:01 0:00:00
# ...
