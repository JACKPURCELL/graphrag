# %%
# !original_dir=$(pwd) && cd /home/ljc/data/graphrag/ && python -m graphrag.index --root "$original_dir"
# Out:
# Logging enabled at r
# /data/jiacheng/graphrag/alltest/dataset4-v3-include-long2/output/20240930-143719
# /reports/indexing-engine.log
# ⠸ GraphRAG Indexer
# ⠸ GraphRAG Indexer e.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# └── create_base_text_units
# ⠴ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   3% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 30 files loaded (1 filtered) ━ 100%  0…
# ⠴ GraphRAG Indexer
# ...
