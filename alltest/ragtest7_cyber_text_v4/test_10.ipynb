# %%
# !original_dir=$(pwd) && cd /home/ljc/data/graphrag/ && python -m graphrag.index --root "$original_dir"
# Out:
# Logging enabled at r
# /data/jiacheng/graphrag/alltest/ragtest7_cyber_text_v4/output/20240930-130827/re
# ports/indexing-engine.log
# ⠸ GraphRAG Indexer
# ⠸ GraphRAG Indexer e.text) - 278 files loaded (0 filtered)  100%  0…
# ├── Loading Input (InputFileType.text) - 278 files loaded (0 filtered)  100%  0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 278 files loaded (0 filtered)  100%  0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 278 files loaded (0 filtered)  100%  0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 278 files loaded (0 filtered)  100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 278 files loaded (0 filtered)  100%  0…
# └── create_base_text_units
# ⠦ GraphRAG Indexer ━━━━━━━━━━━━━━━━━   0% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 278 files loaded (0 filtered)  100%  0…
# └── create_base_text_units
# ⠦ GraphRAG Indexer ━━━━━━━━━━━━━━━━╸ 100% 0:00:01 0:00:00
# ...
