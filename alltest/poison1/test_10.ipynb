# %%
# !python -m graphrag.index --init --root /home/ljc/data/graphrag/alltest/poison1
# Out:
# Initializing project at /home/ljc/data/graphrag/alltest/poison1
# ⠋ GraphRAG Indexer

# %%
# !python -m graphrag.index --root /home/ljc/data/graphrag/alltest/poison1
# Out:
# Logging enabled at r
# /home/ljc/data/graphrag/alltest/poison1/output/20240909-224135/reports/indexing-
# engine.log
# ⠹ GraphRAG Indexer
# ⠹ GraphRAG Indexer e.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# └── create_base_text_units
# ⠼ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   6% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# └── create_base_text_units
# 🚀 create_base_text_units━━   0% -:--:-- 0:00:00
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
#                                   id  ... n_tokens
# 0   cc0dbbd456ec94f96f25793657991734  ...      669
# 1   b324dfcc8a3699591c60646ccaf6e4b0  ...     1035
# 2   c796265ad38bbdc79dc17b2d0aba7e9e  ...      746
# 3   a852b8de65752043f1baf4a502ef7cb3  ...     1200
# 4   1d23704a58bf1d52deb648b7ca463732  ...     1200
# 5   5e3d20242bb7d47bdf0dddf1c7a43741  ...     1200
# 6   dacf9c875e27fd64e2674741cd39d6ab  ...     1001
# 7   e201254a65d111262b3361be30dbaa31  ...      621
# 8   7f6347c263ce28650c650f3f050a4f70  ...      825
# 9   671f5b5587e9f72661c822748941b868  ...      661
# 10  2baa5d7f2a9844571079d991957cec9a  ...     1173
# 11  1bf396570d5a75e44626a2dbcb8cf10b  ...       73
# 12  1cf5059e2eced944286c9661bca717e2  ...      190
# 13  f791c070bd270519bbffc7dd4eb08b3a  ...      686
# 14  8853dc3d23fb41a0bc344445ea1d3927  ...     1200
# 15  a84ec5a02596c7a03aaf3b565cadf903  ...     1200
# 16  c9f3f461ba11cab2e9873a8c4f00e801  ...     1200
# 17  82cf54fe39b605c82333ab89f299f102  ...     1200
# 18  6ee7f2d36395cd37a08858dc0a75875e  ...      276
# 19  2feaa437afffb7674fa0506133b75626  ...      644
# 20  8375d3624fb8b896ff71ffc19d7f91cf  ...      794
# 21  cd0c2f9e8eaf3dddb95a58b3f5fdb8ef  ...      722
# 22  9c1159fac63a5f8b3069d98ad9224551  ...      603
# 23  acebe9382da99effdaf980d1072720f2  ...      875
# 24  aa86232b2bed138127746cc93ab4c0bc  ...      766
#
# [25 rows x 5 columns]
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠴ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠧ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:01
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠋ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:02
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠹ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:03
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠴ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:04
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠇ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:05
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠋ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:06
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠸ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:07
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠴ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:08
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠇ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:09
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠋ GraphRAG Indexer ━━━━━━━━━   0% -:--:-- 0:00:10
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠙ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:-- 0:00:10
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠸ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:-- 0:00:11
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠦ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:-- 0:00:12
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠇ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:-- 0:00:13
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠙ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:-- 0:00:14
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠼ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:-- 0:00:15
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠋ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:-- 0:00:16
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠦ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━━━   8% 0:02:28 0:00:17
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠼ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━━━   8% 0:02:28 0:00:17
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠏ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━━━  12% 0:01:23 0:00:18
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠸ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━━━  12% 0:01:23 0:00:18
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠙ GraphRAG Indexer m━━━━━━━━━━━━━━━━━━━━━━━━━━  16% 0:00:58 0:00:18
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠼ GraphRAG Indexer m━━━━━━━━━━━━━━━━━━━━━━━━━━  16% 0:00:58 0:00:19
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠧ GraphRAG Indexer m━━━━━━━━━━━━━━━━━━━━━━━━━━  16% 0:00:58 0:00:20
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠼ GraphRAG Indexer m━━━━━━━━━━━━━━━━━━━━━━━━━━  16% 0:00:58 0:00:21
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠏ GraphRAG Indexer 90m━━━━━━━━━━━━━━━━━━━━━━━━  20% 0:00:58 0:00:22
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠹ GraphRAG Indexer 90m━━━━━━━━━━━━━━━━━━━━━━━━  20% 0:00:58 0:00:22
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠼ GraphRAG Indexer 90m━━━━━━━━━━━━━━━━━━━━━━━━  20% 0:00:58 0:00:23
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠧ GraphRAG Indexer 90m━━━━━━━━━━━━━━━━━━━━━━━━  20% 0:00:58 0:00:24
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠋ GraphRAG Indexer 90m━━━━━━━━━━━━━━━━━━━━━━━━  20% 0:00:58 0:00:25
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠹ GraphRAG Indexer 90m━━━━━━━━━━━━━━━━━━━━━━━━  20% 0:00:58 0:00:26
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠴ GraphRAG Indexer 90m━━━━━━━━━━━━━━━━━━━━━━━━  20% 0:00:58 0:00:27
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠇ GraphRAG Indexer 90m━━━━━━━━━━━━━━━━━━━━━━━━  20% 0:00:58 0:00:28
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# └── create_base_extracted_entities
# ⠧ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠦ GraphRAG Indexer ━━━  11% 0:00:04 0:00:00
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# ⠇ GraphRAG Indexer ━━━  75% 0:00:01 0:00:00
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠇ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numpy/core/fr
# omnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be
# removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# ⠏ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# └── create_final_entities
# 🚀 create_final_entities-- 0:00:00
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
#                                    id  ...
# description_embedding
# 0    b45241d70f0e43fca764df95b2b81f77  ...  [-0.01393058244138956,
# -0.009974432177841663, ...
# 1    4119fd06010c494caa07f439b333f4c5  ...  [0.011345851235091686,
# -0.012394377961754799, ...
# 2    d3835bf3dda84ead99deadbeac5d0d7d  ...  [-0.018793068826198578,
# -0.009623147547245026,...
# 3    077d2820ae1845bcbb1803379a3d1eae  ...  [-0.04521084576845169,
# 0.01874198578298092, 0....
# 4    3671ea0dd4e84c1a9b02c5ab2c8f4bac  ...  [-0.006457190960645676,
# -0.03139396756887436, ...
# ..                                ...  ...
# ...
# 218  2918130221f94f4387da049b647bfe6a  ...  [0.005230717360973358,
# 0.021138347685337067, 0...
# 219  fd139ac75b0e4777ab67b7423eaaa37f  ...  [-0.017647909000515938,
# -0.04633272811770439, ...
# 220  a701c349eb7142d48ba7efad89caf9d2  ...  [0.006932050455361605,
# -0.004880491178482771, ...
# 221  e5d40a1b17f74b1db5d18279caedb04a  ...  [0.034440018236637115,
# -0.00892602652311325, 0...
# 222  de25d06733d04385825ee082792f5e52  ...  [-0.020429227501153946,
# -0.038361065089702606,...
#
# [447 rows x 8 columns]
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/numba/np/ufun
# c/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version
# 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found
# TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠦ GraphRAG Indexer m-:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠏ GraphRAG Indexer m-:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠹ GraphRAG Indexer m-:--:-- 0:00:01
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠴ GraphRAG Indexer m-:--:-- 0:00:02
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠧ GraphRAG Indexer m-:--:-- 0:00:03
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠹ GraphRAG Indexer m-:--:-- 0:00:04
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠴ GraphRAG Indexer m-:--:-- 0:00:05
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# └── create_final_nodes
# ⠏ GraphRAG Indexer m-:--:-- 0:00:06
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ...
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# 🚀 create_final_text_units
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
#                                   id  ...
# relationship_ids
# 0   cc0dbbd456ec94f96f25793657991734  ...  [32f6f11a7845416b8c6eb9fb0b382140,
# 91407be8c3e...
# 1   b324dfcc8a3699591c60646ccaf6e4b0  ...  [1c7fd5af8d8041e186eae2431fc627cd,
# b16eda56dce...
# 2   c796265ad38bbdc79dc17b2d0aba7e9e  ...  [49f771e31a0c4b35bc39e389f3623509,
# b5fed5609f1...
# 3   a852b8de65752043f1baf4a502ef7cb3  ...  [472b23bb92834173b4118d101040c726,
# bada987ea7d...
# 4   1d23704a58bf1d52deb648b7ca463732  ...  [81869985b45a4fefbbbb23ea118a3de4,
# 49f771e31a0...
# 5   5e3d20242bb7d47bdf0dddf1c7a43741  ...  [42b8584c5a874eb08fbd61f0c18f3ca0,
# 66e098dc431...
# 6   e201254a65d111262b3361be30dbaa31  ...  [3f9a2a2c1c0a424e8b4980ea9d48bdbe,
# fac4e1553a9...
# 7   7f6347c263ce28650c650f3f050a4f70  ...  [4d839a10353e4144a26563b0966721d5,
# aa2ec452728...
# 8   671f5b5587e9f72661c822748941b868  ...  [932e213c57134098a07073febd51dcc2,
# 32dc0b572ad...
# 9   2baa5d7f2a9844571079d991957cec9a  ...  [539d55e7c42e44b59d98f59fae3e0ee1,
# 9593428ad36...
# 10  1bf396570d5a75e44626a2dbcb8cf10b  ...  [bef38889bb86413895d7dd25b4c3137c,
# f770bc07cec...
# 11  1cf5059e2eced944286c9661bca717e2  ...  [a8738c7de11543df930169741381c252,
# 3f8b5b27279...
# 12  f791c070bd270519bbffc7dd4eb08b3a  ...  [3785eeadea9042bfb2e50f16c0397a12,
# c8e5d3afdcb...
# 13  8853dc3d23fb41a0bc344445ea1d3927  ...  [2139b0906dc541e094138a978d070416,
# ff5466607e5...
# 14  a84ec5a02596c7a03aaf3b565cadf903  ...  [824d93d9840a4b7c8b1f31bc6816b497,
# 71f95003936...
# 15  c9f3f461ba11cab2e9873a8c4f00e801  ...  [1e6cabc18fab4c048281fd29d3044438,
# 66e098dc431...
# 16  82cf54fe39b605c82333ab89f299f102  ...  [30b7034c4468473f98ee18d00ee73b33,
# 00f78b85e5b...
# 17  6ee7f2d36395cd37a08858dc0a75875e  ...  [3e460d9f011d4b0b9ccaae7b6a5202de,
# 9d98dece22e...
# 18  2feaa437afffb7674fa0506133b75626  ...  [e1ed13e29ee946d4aaafac50aaa3b68f,
# a51d063ad4c...
# 19  8375d3624fb8b896ff71ffc19d7f91cf  ...  [c1ff9d8e1b8745d6860c34ce26122d79,
# 9d1e6ca9ae8...
# 20  cd0c2f9e8eaf3dddb95a58b3f5fdb8ef  ...  [dc08f6d7398b4b798a3bdccf508a2ad4,
# 9535f4d7540...
# 21  9c1159fac63a5f8b3069d98ad9224551  ...  [c5ddb31e0a9c4b2683e4631283dd505b,
# 5bfefaa0fce...
# 22  acebe9382da99effdaf980d1072720f2  ...  [320d9d91238948a8be67972ccceab878,
# 521a862bb19...
# 23  aa86232b2bed138127746cc93ab4c0bc  ...  [824d93d9840a4b7c8b1f31bc6816b497,
# f209a808f1f...
# 24  dacf9c875e27fd64e2674741cd39d6ab  ...
# None
#
# [25 rows x 6 columns]
# ⠹ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/datashaper/en
# gine/verbs/convert.py:72: FutureWarning: errors='ignore' is deprecated and will
# raise in a future version. Use to_datetime without passing `errors` and catch
# exceptions explicitly instead
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# └── create_base_documents
# /data/jiacheng/miniconda3/envs/common/lib/python3.11/site-packages/datashaper/en
# gine/verbs/convert.py:72: UserWarning: Could not infer format, so each element
# will be parsed individually, falling back to `dateutil`. To ensure parsing is
# consistent and as-expected, please specify a format.
#   datetime_column = pd.to_datetime(column, errors="ignore")
# ⠦ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# └── create_base_documents
# 🚀 create_base_documents
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
#                                   id  ...                   title
# 0   45118b491c6d36b4a415322d2c444105  ...                  EU.txt
# 1   57bf53f538aec812a46d791c2d841fef  ...                  sf.txt
# 2   4c2ff161b5f148f60ada3fbd03391301  ...                 las.txt
# 3   ae9e38d22d19e470bb73a77fbb6b60f8  ...             seattle.txt
# 4   9b6b9d1a58bc691dd54a34680e736e8d  ...                mars.txt
# 5   d6061301be2e033108f2e34a3ea8f22f  ...                lyon.txt
# 6   713939d032c2c02215b16dd704885c0b  ...                wash.txt
# 7   10dbe8991bb9a7ab1dda37e9ccbedd78  ...                nice.txt
# 8   19c6b20ecbcf8b0a095370de601ae385  ...    adv_texts_direct.txt
# 9   0134252ef584e1c209f4b4937c1d7a4f  ...                  US.txt
# 10  ef613ab86e387aabcf046b426ee32221  ...                  dc.txt
# 11  63486c02b166324e26ba2c8d04b86f63  ...                  un.txt
# 12  dd4cc25417ca1866236c0f308e7f8ee3  ...              france.txt
# 13  6356824a0133faf02f0c2416c296c1d0  ...  adv_texts_indirect.txt
# 14  474b35b12bfb44f1235cd856dcae3b43  ...               paris.txt
# 15  5a03438903936014f36728865626c03b  ...            westeuro.txt
# 16  147a4bae12320a91e5843421457c4c0e  ...                  ny.txt
#
# [17 rows x 4 columns]
# ⠧ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
# 🚀 create_final_documents
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
#                                   id  ...                   title
# 0   45118b491c6d36b4a415322d2c444105  ...                  EU.txt
# 1   57bf53f538aec812a46d791c2d841fef  ...                  sf.txt
# 2   4c2ff161b5f148f60ada3fbd03391301  ...                 las.txt
# 3   ae9e38d22d19e470bb73a77fbb6b60f8  ...             seattle.txt
# 4   9b6b9d1a58bc691dd54a34680e736e8d  ...                mars.txt
# 5   d6061301be2e033108f2e34a3ea8f22f  ...                lyon.txt
# 6   713939d032c2c02215b16dd704885c0b  ...                wash.txt
# 7   10dbe8991bb9a7ab1dda37e9ccbedd78  ...                nice.txt
# 8   19c6b20ecbcf8b0a095370de601ae385  ...    adv_texts_direct.txt
# 9   0134252ef584e1c209f4b4937c1d7a4f  ...                  US.txt
# 10  ef613ab86e387aabcf046b426ee32221  ...                  dc.txt
# 11  63486c02b166324e26ba2c8d04b86f63  ...                  un.txt
# 12  dd4cc25417ca1866236c0f308e7f8ee3  ...              france.txt
# 13  6356824a0133faf02f0c2416c296c1d0  ...  adv_texts_indirect.txt
# 14  474b35b12bfb44f1235cd856dcae3b43  ...               paris.txt
# 15  5a03438903936014f36728865626c03b  ...            westeuro.txt
# 16  147a4bae12320a91e5843421457c4c0e  ...                  ny.txt
#
# [17 rows x 4 columns]
# ⠋ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
# ⠙ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 17 files loaded (0 filtered) ━ 100%  0…
# ├── create_base_text_units
# ├── create_base_extracted_entities
# ├── create_summarized_entities
# ├── create_base_entity_graph
# ├── create_final_entities
# ├── create_final_nodes
# ├── create_final_communities
# ├── join_text_units_to_entity_ids
# ├── create_final_relationships
# ├── join_text_units_to_relationship_ids
# ├── create_final_community_reports
# ├── create_final_text_units
# ├── create_base_documents
# └── create_final_documents
# 🚀 All workflows completed successfully.

# %%
import os
import networkx as nx
import matplotlib.pyplot as plt

# Step 1: Find the folder with the latest modification time
output_path = '/home/ljc/data/graphrag/alltest/poison1/output'
folders = [os.path.join(output_path, d) for d in os.listdir(output_path) if os.path.isdir(os.path.join(output_path, d))]
latest_folder = max(folders, key=os.path.getmtime)

# Step 2: Find the artifacts/merged_graph.graphml file in that folder
graphml_file_path = os.path.join(latest_folder, 'artifacts', 'merged_graph.graphml')

# Check if file exists
if not os.path.isfile(graphml_file_path):
    print(f"GraphML file not found: {graphml_file_path}")
else:
    # Step 3: Read the GraphML file and visualize it
    graph = nx.read_graphml(graphml_file_path)
    
    # Draw the graph
    plt.figure(figsize=(35, 35))  # Increase figure size
    pos = nx.kamada_kawai_layout(graph)  # Use kamada_kawai layout
    
    # Draw nodes and edges
    nx.draw_networkx_nodes(graph, pos, node_size=700, node_color='skyblue')
    nx.draw_networkx_edges(graph, pos, edge_color='gray', alpha=0.5)
    
    # Draw labels with better positioning
    nx.draw_networkx_labels(graph, pos, font_size=8, font_weight='regular', verticalalignment='bottom')
    
    plt.title('Optimized GraphML Visualization')
    plt.axis('off')
    plt.show()

# %%
# !python -m graphrag.query --root ./ragtest6 --method local \
    "Please help me plan my trip to the capital of France"
# Out:
# INFO: Reading settings from ragtest6/settings.yaml
#
# INFO: Vector Store Args: {}
# creating llm client with {'api_key': 'REDACTED,len=56', 'type': "openai_chat", 'model': 'gpt-4o-2024-08-06', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': None, 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
# creating embedding llm client with {'api_key': 'REDACTED,len=56', 'type': "openai_embedding", 'model': 'text-embedding-3-small', 'max_tokens': 4000, 'temperature': 0, 'top_p': 1, 'n': 1, 'request_timeout': 180.0, 'api_base': None, 'api_version': None, 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': None, 'model_supports_json': None, 'tokens_per_minute': 0, 'requests_per_minute': 0, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 25}
#
# SUCCESS: Local Search Response:
# # Planning Your Trip to Paris, the Capital of France
#
# Paris, often referred to as the "City of Light," is a vibrant metropolis known for its rich history, cultural landmarks, and significant role in global affairs. As the capital of France, it offers a diverse array of attractions and activities that cater to all interests. Here’s a guide to help you plan your trip to this iconic city.
#
# ## Cultural and Historical Attractions
#
# Paris is home to some of the world's most renowned cultural institutions. The **Louvre**, the most-visited art museum globally, houses an extensive collection of art and historical artifacts, including the famous Mona Lisa [Data: Entities (98); Relationships (140)]. Another must-visit is the **Musée d'Orsay**, which is celebrated for its impressive collection of French Impressionist art [Data: Entities (99); Relationships (141)]. For those interested in modern and contemporary art, the **Pompidou Centre** is a notable destination [Data: Entities (102); Relationships (144)].
#
# ## International Organizations and Economic Influence
#
# Paris is not only a cultural hub but also a center for international diplomacy and economic governance. It hosts several key international organizations, such as **UNESCO** and the **OECD**, which play pivotal roles in global policy-making [Data: Entities (49, 105); Relationships (85, 147, 150)]. The presence of the **European Banking Authority** and the **European Securities and Markets Authority** underscores Paris's importance in financial regulation within the European Union [Data: Entities (111, 112); Relationships (153, 154)].
#
# ## Transportation and Accessibility
#
# Getting around Paris is convenient thanks to its extensive transportation network. The city is served by two major international airports, **Charles de Gaulle** and **Orly**, which are key gateways for international travelers [Data: Entities (94, 95); Relationships (136, 137)]. The **Paris Métro** is one of the busiest subway systems in Europe, making it easy to navigate the city and reach various attractions [Data: Entities (96); Relationships (138)].
#
# ## Sporting and Recreational Activities
#
# Paris has a rich sporting legacy, having hosted numerous international events such as the **Summer Olympics**, **FIFA World Cup**, and the **Tour de France**, which finishes on the iconic Avenue des Champs-Élysées [Data: Entities (117, 118, 122); Relationships (159, 160, 164)]. If you’re a sports enthusiast, consider visiting the **Stade de France**, a large stadium that hosts various major sporting events [Data: Entities (115); Relationships (157)].
#
# ## Conclusion
#
# Paris offers a unique blend of history, culture, and modernity, making it a perfect destination for travelers seeking diverse experiences. Whether you're exploring its world-class museums, attending international events, or simply enjoying the local cuisine and fashion, Paris promises an unforgettable journey. Make sure to plan your itinerary to include these highlights and immerse yourself in the vibrant life of this global city.
