# %%
# !original_dir=$(pwd) && cd /home/ljc/data/graphrag/ && python -m graphrag.index --root "$original_dir"
# Out:
# Logging enabled at r
# /data/jiacheng/graphrag/alltest/ragtest7_cyber_text_baseline/output/20240929-211
# 639/reports/indexing-engine.log
# ⠸ GraphRAG Indexer
# ⠸ GraphRAG Indexer e.text) - 276 files loaded (0 filtered)  100%  0…
# ├── Loading Input (InputFileType.text) - 276 files loaded (0 filtered)  100%  0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 276 files loaded (0 filtered)  100%  0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 276 files loaded (0 filtered)  100%  0…
# ⠸ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 276 files loaded (0 filtered)  100%  0…
# ⠴ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 276 files loaded (0 filtered)  100%  0…
# └── create_base_text_units
# ⠦ GraphRAG Indexer ━━━━━━━━━━━━━━━━━   0% -:--:-- 0:00:00
# ├── Loading Input (InputFileType.text) - 276 files loaded (0 filtered)  100%  0…
# ⠦ GraphRAG Indexer
# ...
